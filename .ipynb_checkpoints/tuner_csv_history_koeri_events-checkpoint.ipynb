# %% [markdown]
# # Earthquake in Turkey

# %% [markdown]
# ## Data Source
#
# The origin data table is embedded/nested at http://www.koeri.boun.edu.tr/sismo/2/latest-earthquakes/automatic-solutions/,
# being updated daily per events happened in Turkey and surounding areas.
#
# From 16 Jan 2023 and onwards, I started to grab down the dataset daily and manually, and put/merge into a csv file named -
# "data/koeri.boun.edu.tr-lasteq-autosol_from_2023-01-16_tab.csv". This is a very time consuming.
#
#
# ## Progress
#
# #### Update - 8 March 2023
# * Scraping the numbered pages was successful.
# * http://sc3.koeri.boun.edu.tr/eqevents/events1.html
# * http://sc3.koeri.boun.edu.tr/eqevents/events2.html
# * ...
# * http://sc3.koeri.boun.edu.tr/eqevents/events32.html
# * http://sc3.koeri.boun.edu.tr/eqevents/events33.html
#
# #### Update - 7 March 2023
# * Scraping the first page was successful.
# * http://sc3.koeri.boun.edu.tr/eqevents/events.html
#
# #### Update - 4 March 2023
# * Create a SQLite3 db and save the dataframe of Historic data into it - Successful.
#
# #### Update - 2 March 2023
# * The loading of the Historic dataset from a CSV file is successful.
#
#
# ## Planning
#
# Thinking about -
# * to load up the historic data - Done!
# * to build a local database (SQLite3?) to save what we have grabbed down so far - Done!
# * to run a webScraping task to grab down the daily updates from the website mentioned above - Done!
# * to merge the historic dataset and the realtime daily updates into one database - Done!
# <br><br>
# * Finnally implement this into a .py file with a scheduled daily web-scraper - to be Done.

# %% [markdown]
# ## Prep Libraries

# %%
# Load up libraries
import pandas as pd
import folium
import webbrowser
import datetime as dt
import sqlite3

print('Pandas: ', pd.__version__)
print('Folium: ', folium.__version__)
# Out:
# Pandas:  1.5.3
# Folium:  0.14.0

# %% [markdown]
# ## Web Scrapping Real-time Data
#
#
# More in-depth digging reveals that the actual tables are in HTML format as below (34 counts):
#
# * http://sc3.koeri.boun.edu.tr/eqevents/events.html
# * http://sc3.koeri.boun.edu.tr/eqevents/events1.html
# * http://sc3.koeri.boun.edu.tr/eqevents/events2.html
# * ...
# * http://sc3.koeri.boun.edu.tr/eqevents/events32.html
# * http://sc3.koeri.boun.edu.tr/eqevents/events33.html
#
# Then the target page is being reset to: http://sc3.koeri.boun.edu.tr/eqevents/events{i}.html and
# the scrapping task focus on the first a few pages if the job runner be turned on every day.
#
# It turns out the first page naming convention **differs** from the rest, then we have to scrap them into seperate dataframes and merge the two.
#
# Then merge the dataframe to the SQLite3 database.

# %%
import requests
from bs4 import BeautifulSoup

# send a GET request to the URL - the first page
url = "http://sc3.koeri.boun.edu.tr/eqevents/events.html"
response = requests.get(url)
# parse the HTML content of the page with BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

data0 = []
# find the table element and iterate over its rows
table = soup.find("table", {'class': 'index'})
rows = table.find_all("tr", {'class': 'trIndevnrow'})[1:]
for row in rows:
    # get the cells in the row
    cols = row.find_all("td")
    # get the earthquake information from the columns
    origintimeutc = cols[0].text.strip()
    magnitude = cols[1].text.strip()
    magType = cols[2].text.strip()
    lat = cols[3].text.strip()
    long = cols[4].text.strip()
    depth = cols[5].text.strip()
    region = cols[6].text.strip()
    am = cols[7].text.strip()
    lastUpd = cols[8].text.strip()
    kml = cols[9].text.strip()
    
    data0.append([origintimeutc, magnitude, magType, lat, long, depth, region, am, lastUpd, kml])
        
df0 = pd.DataFrame(data0, columns=['origin-time-utc', 'magnitude', 'magType', 'latitude', 'longitude', 'depthKM', 'region', 'measMethod', 'updTime', 'attribute'])
df0
# Out:
#         origin-time-utc magnitude magType    latitude   longitude depthKM  \
# 0   2023/03/08 09:26:29       3.6     MLv  37.9047° N  36.7365° E       0
# 1   2023/03/08 08:41:55       3.3     MLv  36.3025° N  36.0681° E       9
# 2   2023/03/08 07:32:07       2.9     MLv  38.6948° N  35.3348° E       0
# 3   2023/03/08 03:23:37       3.4     MLv  38.0795° N  37.2665° E       0
# 4   2023/03/08 02:52:37       2.0     MLv  36.6640° N  33.5468° E      10
# 5   2023/03/08 01:07:14       2.3     MLv  38.6725° N  39.9025° E      10
# 6   2023/03/07 23:25:35       2.5     MLv  37.2162° N  36.9818° E       7
# 7   2023/03/07 22:23:09       3.3     MLv  38.0850° N  38.6343° E       0
# 8   2023/03/07 20:44:26       3.4     MLv  36.1941° N  36.0249° E       7
# 9   2023/03/07 20:37:14       2.6     MLv  37.8864° N  36.6156° E       7
# 10  2023/03/07 20:18:18       3.6     MLv  38.1500° N  38.1354° E       0
# 11  2023/03/07 19:52:04       2.9     MLv  38.6526° N  35.2945° E       0
#
#                   region measMethod              updTime       attribute
# 0   Merkez-Kahramanmaras          A  2023/03/08 09:30:28  Stations Event
# 1           Merkez-Hatay          A  2023/03/08 08:45:45  Stations Event
# 2        Hacilar-Kayseri          A  2023/03/08 07:35:01  Stations Event
# 3   Nurhak-Kahramanmaras          A  2023/03/08 03:26:58  Stations Event
# 4             Mut-Mersin          M  2023/03/08 06:02:41  Stations Event
# 5            Palu-Elazig          M  2023/03/08 06:38:39  Stations Event
# 6      Nurdagi-Gaziantep          A  2023/03/07 23:29:12  Stations Event
# 7        Sincik-Adiyaman          A  2023/03/07 22:26:38  Stations Event
# 8         Samandag-Hatay          M  2023/03/08 06:13:18  Stations Event
# 9   Merkez-Kahramanmaras          A  2023/03/07 20:41:20  Stations Event
# 10     Yesilyurt-Malatya          A  2023/03/07 20:22:06  Stations Event
# 11        incesu-Kayseri          A  2023/03/07 19:54:49  Stations Event

# %%
import requests
from bs4 import BeautifulSoup

data1 = []
# loop through the pages 1-5
for i in range(1,9):
    # specify the URL to scrape
    url = f"http://sc3.koeri.boun.edu.tr/eqevents/events{i}.html"
    
    # make a GET request to the URL and get the HTML content
    response = requests.get(url)
    html_content = response.content
    
    # parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # find the earthquake table
    eq_table = soup.find('table', {'class': 'index'})
    
    # loop through the rows of the table
    for row in eq_table.find_all('tr', {'class': 'trIndevnrow'})[1:]:
        # get the columns of the row
        cols = row.find_all('td')
        
        # get the earthquake information from the columns
        origintimeutc = cols[0].text.strip()
        magnitude = cols[1].text.strip()
        magType = cols[2].text.strip()
        lat = cols[3].text.strip()
        long = cols[4].text.strip()
        depth = cols[5].text.strip()
        region = cols[6].text.strip()
        am = cols[7].text.strip()
        lastUpd = cols[8].text.strip()
        kml = cols[9].text.strip()
        
        data1.append([origintimeutc, magnitude, magType, lat, long, depth, region, am, lastUpd, kml])
        
        # print the earthquake information
        #print(f"{origintimeutc}, {magnitude}, {magType}, {lat}, {long}, {depth}, {region}, {am}, {lastUpd}, {kml}")
        
df1 = pd.DataFrame(data1, columns = ["origin-time-utc", "magnitude", "magType", "latitude", "longitude", "depthKM", "region", "measMethod", "updTime", "attribute"])
df1
# Out:
#          origin-time-utc magnitude magType    latitude   longitude depthKM  \
# 0    2023/03/07 16:27:42       2.6     MLv  37.5458° N  37.3444° E      11
# 1    2023/03/07 15:08:23       3.2     MLv  38.1924° N  38.7374° E       5
# 2    2023/03/07 14:18:20       4.4     MLv  38.8129° N  37.4908° E       0
# 3    2023/03/07 12:15:56       3.6     MLv  38.7094° N  35.2505° E       0
# 4    2023/03/07 11:47:29       4.9     MLv  38.7653° N  35.1544° E       0
# ..                   ...       ...     ...         ...         ...     ...
# 102  2023/03/01 11:00:20       3.0     MLv  36.2457° N  36.1725° E      13
# 103  2023/03/01 10:00:17       3.3     MLv  36.8784° N  29.0048° E       0
# 104  2023/03/01 08:55:53       3.1     MLv  38.7360° N  35.3522° E       0
# 105  2023/03/01 06:40:51       2.5     MLv  39.1534° N  29.0973° E       6
# 106  2023/03/01 05:41:39       2.8     MLv  35.9824° N  31.2063° E       5
#
#                       region measMethod              updTime       attribute
# 0     Pazarcik-Kahramanmaras          A  2023/03/07 16:31:13  Stations Event
# 1            Puturge-Malatya          M  2023/03/08 06:34:08  Stations Event
# 2                Gurun-Sivas          A  2023/03/07 14:44:06  Stations Event
# 3             incesu-Kayseri          A  2023/03/07 12:19:38  Stations Event
# 4             incesu-Kayseri          A  2023/03/07 18:41:46  Stations Event
# ..                       ...        ...                  ...             ...
# 102             Merkez-Hatay          A  2023/03/01 11:03:53  Stations Event
# 103            Dalaman-Mugla          A  2023/03/01 10:30:37  Stations Event
# 104          Hacilar-Kayseri          A  2023/03/01 08:59:08  Stations Event
# 105            Simav-Kutahya          A  2023/03/01 06:43:25  Stations Event
# 106  Antalya Korfezi-AKDENIZ          M  2023/03/01 05:58:02  Stations Event
#
# [107 rows x 10 columns]

# %%
df1.tail()
# Out:
#          origin-time-utc magnitude magType    latitude   longitude depthKM  \
# 102  2023/03/01 11:00:20       3.0     MLv  36.2457° N  36.1725° E      13
# 103  2023/03/01 10:00:17       3.3     MLv  36.8784° N  29.0048° E       0
# 104  2023/03/01 08:55:53       3.1     MLv  38.7360° N  35.3522° E       0
# 105  2023/03/01 06:40:51       2.5     MLv  39.1534° N  29.0973° E       6
# 106  2023/03/01 05:41:39       2.8     MLv  35.9824° N  31.2063° E       5
#
#                       region measMethod              updTime       attribute
# 102             Merkez-Hatay          A  2023/03/01 11:03:53  Stations Event
# 103            Dalaman-Mugla          A  2023/03/01 10:30:37  Stations Event
# 104          Hacilar-Kayseri          A  2023/03/01 08:59:08  Stations Event
# 105            Simav-Kutahya          A  2023/03/01 06:43:25  Stations Event
# 106  Antalya Korfezi-AKDENIZ          M  2023/03/01 05:58:02  Stations Event

# %%
# Concatenate 2 realtime dataframes
rtDF = pd.concat([df0, df1]).drop_duplicates()
rtDF
# Out:
#          origin-time-utc magnitude magType    latitude   longitude depthKM  \
# 0    2023/03/08 09:26:29       3.6     MLv  37.9047° N  36.7365° E       0
# 1    2023/03/08 08:41:55       3.3     MLv  36.3025° N  36.0681° E       9
# 2    2023/03/08 07:32:07       2.9     MLv  38.6948° N  35.3348° E       0
# 3    2023/03/08 03:23:37       3.4     MLv  38.0795° N  37.2665° E       0
# 4    2023/03/08 02:52:37       2.0     MLv  36.6640° N  33.5468° E      10
# ..                   ...       ...     ...         ...         ...     ...
# 102  2023/03/01 11:00:20       3.0     MLv  36.2457° N  36.1725° E      13
# 103  2023/03/01 10:00:17       3.3     MLv  36.8784° N  29.0048° E       0
# 104  2023/03/01 08:55:53       3.1     MLv  38.7360° N  35.3522° E       0
# 105  2023/03/01 06:40:51       2.5     MLv  39.1534° N  29.0973° E       6
# 106  2023/03/01 05:41:39       2.8     MLv  35.9824° N  31.2063° E       5
#
#                       region measMethod              updTime       attribute
# 0       Merkez-Kahramanmaras          A  2023/03/08 09:30:28  Stations Event
# 1               Merkez-Hatay          A  2023/03/08 08:45:45  Stations Event
# 2            Hacilar-Kayseri          A  2023/03/08 07:35:01  Stations Event
# 3       Nurhak-Kahramanmaras          A  2023/03/08 03:26:58  Stations Event
# 4                 Mut-Mersin          M  2023/03/08 06:02:41  Stations Event
# ..                       ...        ...                  ...             ...
# 102             Merkez-Hatay          A  2023/03/01 11:03:53  Stations Event
# 103            Dalaman-Mugla          A  2023/03/01 10:30:37  Stations Event
# 104          Hacilar-Kayseri          A  2023/03/01 08:59:08  Stations Event
# 105            Simav-Kutahya          A  2023/03/01 06:43:25  Stations Event
# 106  Antalya Korfezi-AKDENIZ          M  2023/03/01 05:58:02  Stations Event
#
# [119 rows x 10 columns]

# %% [markdown]
# ## Historic Data Loading

# %%
# Load u history data from csv file
histDF = pd.read_csv("data/koeri.boun.edu.tr-lasteq-autosol_from_2023-01-16_tab.csv", sep='\t')
histDF.head()
# Out:
#        origin-time-utc  mag mag-type    latitude    longitude  depth(km)  \
# 0  2023/03/02 07:29:24  2.7      MLv  37.1320° N   36.7474° E       12.0
# 1  2023/03/02 06:47:33  3.1      MLv  35.4990° N   32.3050° E       13.0
# 2  2023/03/02 06:29:48  3.4      MLv  38.1216° N   38.5098° E        0.0
# 3  2023/03/02 06:14:47  5.2       mb  43.5305° N  147.2541° E       10.0
# 4  2023/03/02 06:05:54  3.0      MLv  38.0804° N   37.1576° E        7.0
#
#                   region a/m         time-updated             kml
# 0      Nurdagi-Gaziantep   A  2023/03/02 07:31:55  Stations Event
# 1          Cyprus Region   M  2023/03/02 07:34:57  Stations Event
# 2        Sincik-Adiyaman   A  2023/03/02 06:33:00  Stations Event
# 3          Kuril Islands   A  2023/03/02 06:43:49  Stations Event
# 4  Ekinozu-Kahramanmaras   A  2023/03/02 06:08:47  Stations Event

# %%
histDF['depth(km)'] = histDF['depth(km)'].replace('-', 0).astype("float")
histDF.columns = ["origin-time-utc", "magnitude", "magType", "latitude", "longitude", "depthKM", "region", "measMethod", "updTime", "attribute"]
histDF
# Out:
#           origin-time-utc  magnitude magType    latitude    longitude  \
# 0     2023/03/02 07:29:24        2.7     MLv  37.1320° N   36.7474° E
# 1     2023/03/02 06:47:33        3.1     MLv  35.4990° N   32.3050° E
# 2     2023/03/02 06:29:48        3.4     MLv  38.1216° N   38.5098° E
# 3     2023/03/02 06:14:47        5.2      mb  43.5305° N  147.2541° E
# 4     2023/03/02 06:05:54        3.0     MLv  38.0804° N   37.1576° E
# ...                   ...        ...     ...         ...          ...
# 1896  2023/01/16 22:19:00        2.4     MLv  39.5278° N   25.9722° E
# 1897  2023/01/16 22:07:00        3.1     MLv  39.3431° N   26.2384° E
# 1898  2023/01/16 22:05:00        3.4     MLv  36.9406° N   26.5903° E
# 1899  2023/01/16 21:58:00        2.9     MLv  39.4010° N   26.2998° E
# 1900  2023/01/16 21:35:00        2.5     MLv  39.5220° N   25.9825° E
#
#       depthKM                       region measMethod              updTime  \
# 0        12.0            Nurdagi-Gaziantep          A  2023/03/02 07:31:55
# 1        13.0                Cyprus Region          M  2023/03/02 07:34:57
# 2         0.0              Sincik-Adiyaman          A  2023/03/02 06:33:00
# 3        10.0                Kuril Islands          A  2023/03/02 06:43:49
# 4         7.0        Ekinozu-Kahramanmaras          A  2023/03/02 06:08:47
# ...       ...                          ...        ...                  ...
# 1896      0.0                   Aegean Sea          M  2023/01/17 10:47:00
# 1897      7.0     Midilli Adasi-Ege Denizi          M  2023/01/17 10:44:00
# 1898      7.0  Dodecanese Islands,  Greece          M  2023/01/17 10:41:00
# 1899      3.0                       Turkey          M  2023/01/17 10:24:00
# 1900      7.0  Ayvacik Aciklari-EGE DENIZI          M  2023/01/17 09:38:00
#
#            attribute
# 0     Stations Event
# 1     Stations Event
# 2     Stations Event
# 3     Stations Event
# 4     Stations Event
# ...              ...
# 1896  Stations Event
# 1897  Stations Event
# 1898  Stations Event
# 1899  Stations Event
# 1900  Stations Event
#
# [1901 rows x 10 columns]

# %% [markdown]
# ## Merge Realtime DF and Historic DF

# %%
# Concatenate the realtime & historic dataframes
totalDF = pd.concat([rtDF, histDF]).drop_duplicates()
totalDF.describe()
# Out:
#             origin-time-utc  magnitude magType    latitude   longitude  \
# count                  2019     2019.0    2019        2019        2019
# unique                 1992       79.0       3        1433        1674
# top     2023/03/01 14:27:12        3.3     MLv  38.0832° N  36.6422° E
# freq                      2      104.0    1912          10           6
#
#         depthKM                region measMethod              updTime  \
# count    2017.0                  2019       2019                 2019
# unique    111.0                   278          2                 1965
# top         0.0  Goksun-Kahramanmaras          A  2023/02/06 15:55:00
# freq      876.0                   284       1664                    4
#
#              attribute
# count             2019
# unique               1
# top     Stations Event
# freq              2019

# %%
# Sort ob Timestamp
totalDF.sort_values(by='origin-time-utc')
totalDF.head()
# Out:
#        origin-time-utc magnitude magType    latitude   longitude depthKM  \
# 0  2023/03/08 09:26:29       3.6     MLv  37.9047° N  36.7365° E       0
# 1  2023/03/08 08:41:55       3.3     MLv  36.3025° N  36.0681° E       9
# 2  2023/03/08 07:32:07       2.9     MLv  38.6948° N  35.3348° E       0
# 3  2023/03/08 03:23:37       3.4     MLv  38.0795° N  37.2665° E       0
# 4  2023/03/08 02:52:37       2.0     MLv  36.6640° N  33.5468° E      10
#
#                  region measMethod              updTime       attribute
# 0  Merkez-Kahramanmaras          A  2023/03/08 09:30:28  Stations Event
# 1          Merkez-Hatay          A  2023/03/08 08:45:45  Stations Event
# 2       Hacilar-Kayseri          A  2023/03/08 07:35:01  Stations Event
# 3  Nurhak-Kahramanmaras          A  2023/03/08 03:26:58  Stations Event
# 4            Mut-Mersin          M  2023/03/08 06:02:41  Stations Event

# %% [markdown]
# ## Save Dataframe to a SQLite3 database

# %%
# SAVE RESULTANT DF TO SQLITE3 DATABASE

# Create sqlite database and cursor
conn = sqlite3.connect('data/earthquake-in-turkey.db')
c = conn.cursor()
# Create the table of quaketk
c.execute("""CREATE TABLE IF NOT EXISTS quaketk (
            origintimeutc text,
            magnitude real,
            magtype text,
            latitude real,
            longitude real,
            depthkm real,
            region text,
            measmethod text,
            updtime text,
            attribute text
            )""")
conn.commit()

# test
test = conn.execute('SELECT * from quaketk')
names = [description[0] for description in test.description]
print(names)
# Out:
# ['origintimeutc', 'magnitude', 'magtype', 'latitude', 'longitude', 'depthkm', 'region', 'measmethod', 'updtime', 'attribute']

# %%
# Save the dataframe to database
totalDF.columns = ['origintimeutc', 'magnitude', 'magtype', 'latitude', 'longitude', 'depthkm', 'region', 'measmethod', 'updtime', 'attribute']
totalDF.to_sql('quaketk', conn, if_exists='append', index=False)

# verify if the dataframe has been saved to sqlite DB or not, please uncomment the following command
conn.execute('SELECT * from quaketk').fetchall()
# Out:
# [('2023/03/08 09:26:29',
#   3.6,
#   'MLv',
#   '37.9047° N',
#   '36.7365° E',
#   0.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/03/08 09:30:28',
#   'Stations Event'),
#  ('2023/03/08 08:41:55',
#   3.3,
#   'MLv',
#   '36.3025° N',
#   '36.0681° E',
#   9.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/03/08 08:45:45',
#   'Stations Event'),
#  ('2023/03/08 07:32:07',
#   2.9,
#   'MLv',
#   '38.6948° N',
#   '35.3348° E',
#   0.0,
#   'Hacilar-Kayseri',
#   'A',
#   '2023/03/08 07:35:01',
#   'Stations Event'),
#  ('2023/03/08 03:23:37',
#   3.4,
#   'MLv',
#   '38.0795° N',
#   '37.2665° E',
#   0.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/03/08 03:26:58',
#   'Stations Event'),
#  ('2023/03/08 02:52:37',
#   2.0,
#   'MLv',
#   '36.6640° N',
#   '33.5468° E',
#   10.0,
#   'Mut-Mersin',
#   'M',
#   '2023/03/08 06:02:41',
#   'Stations Event'),
#  ('2023/03/08 01:07:14',
#   2.3,
#   'MLv',
#   '38.6725° N',
#   '39.9025° E',
#   10.0,
#   'Palu-Elazig',
#   'M',
#   '2023/03/08 06:38:39',
#   'Stations Event'),
#  ('2023/03/07 23:25:35',
#   2.5,
#   'MLv',
#   '37.2162° N',
#   '36.9818° E',
#   7.0,
#   'Nurdagi-Gaziantep',
#   'A',
#   '2023/03/07 23:29:12',
#   'Stations Event'),
#  ('2023/03/07 22:23:09',
#   3.3,
#   'MLv',
#   '38.0850° N',
#   '38.6343° E',
#   0.0,
#   'Sincik-Adiyaman',
#   'A',
#   '2023/03/07 22:26:38',
#   'Stations Event'),
#  ('2023/03/07 20:44:26',
#   3.4,
#   'MLv',
#   '36.1941° N',
#   '36.0249° E',
#   7.0,
#   'Samandag-Hatay',
#   'M',
#   '2023/03/08 06:13:18',
#   'Stations Event'),
#  ('2023/03/07 20:37:14',
#   2.6,
#   'MLv',
#   '37.8864° N',
#   '36.6156° E',
#   7.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/03/07 20:41:20',
#   'Stations Event'),
#  ('2023/03/07 20:18:18',
#   3.6,
#   'MLv',
#   '38.1500° N',
#   '38.1354° E',
#   0.0,
#   'Yesilyurt-Malatya',
#   'A',
#   '2023/03/07 20:22:06',
#   'Stations Event'),
#  ('2023/03/07 19:52:04',
#   2.9,
#   'MLv',
#   '38.6526° N',
#   '35.2945° E',
#   0.0,
#   'incesu-Kayseri',
#   'A',
#   '2023/03/07 19:54:49',
#   'Stations Event'),
#  ('2023/03/07 16:27:42',
#   2.6,
#   'MLv',
#   '37.5458° N',
#   '37.3444° E',
#   11.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/03/07 16:31:13',
#   'Stations Event'),
#  ('2023/03/07 15:08:23',
#   3.2,
#   'MLv',
#   '38.1924° N',
#   '38.7374° E',
#   5.0,
#   'Puturge-Malatya',
#   'M',
#   '2023/03/08 06:34:08',
#   'Stations Event'),
#  ('2023/03/07 14:18:20',
#   4.4,
#   'MLv',
#   '38.8129° N',
#   '37.4908° E',
#   0.0,
#   'Gurun-Sivas',
#   'A',
#   '2023/03/07 14:44:06',
#   'Stations Event'),
#  ('2023/03/07 12:15:56',
#   3.6,
#   'MLv',
#   '38.7094° N',
#   '35.2505° E',
#   0.0,
#   'incesu-Kayseri',
#   'A',
#   '2023/03/07 12:19:38',
#   'Stations Event'),
#  ('2023/03/07 11:47:29',
#   4.9,
#   'MLv',
#   '38.7653° N',
#   '35.1544° E',
#   0.0,
#   'incesu-Kayseri',
#   'A',
#   '2023/03/07 18:41:46',
#   'Stations Event'),
#  ('2023/03/07 11:13:45',
#   3.9,
#   'MLv',
#   '38.0905° N',
#   '36.5836° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/07 11:17:38',
#   'Stations Event'),
#  ('2023/03/07 09:35:07',
#   2.8,
#   'MLv',
#   '38.0585° N',
#   '36.7511° E',
#   4.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/07 09:39:09',
#   'Stations Event'),
#  ('2023/03/07 08:36:29',
#   3.7,
#   'MLv',
#   '40.8097° N',
#   '27.7612° E',
#   8.0,
#   'Marmara Denizi (Bati)',
#   'M',
#   '2023/03/07 08:54:59',
#   'Stations Event'),
#  ('2023/03/07 07:40:02',
#   3.6,
#   'MLv',
#   '38.2150° N',
#   '38.6673° E',
#   0.0,
#   'Puturge-Malatya',
#   'A',
#   '2023/03/07 07:43:47',
#   'Stations Event'),
#  ('2023/03/07 07:13:41',
#   2.8,
#   'MLv',
#   '38.4994° N',
#   '37.7335° E',
#   5.0,
#   'Darende-Malatya',
#   'M',
#   '2023/03/07 07:33:02',
#   'Stations Event'),
#  ('2023/03/07 05:55:24',
#   3.2,
#   'MLv',
#   '38.1198° N',
#   '37.8415° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/03/07 05:59:16',
#   'Stations Event'),
#  ('2023/03/07 04:45:26',
#   1.8,
#   'MLv',
#   '39.3697° N',
#   '26.2594° E',
#   7.0,
#   'Midilli Adasi-Ege Denizi',
#   'M',
#   '2023/03/07 06:33:38',
#   'Stations Event'),
#  ('2023/03/07 01:35:55',
#   2.9,
#   'MLv',
#   '38.7987° N',
#   '37.4547° E',
#   5.0,
#   'Gurun-Sivas',
#   'M',
#   '2023/03/07 06:22:49',
#   'Stations Event'),
#  ('2023/03/06 23:41:14',
#   3.4,
#   'MLv',
#   '36.1157° N',
#   '36.1890° E',
#   4.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/03/07 00:42:16',
#   'Stations Event'),
#  ('2023/03/06 21:32:19',
#   3.0,
#   'MLv',
#   '39.9994° N',
#   '40.8197° E',
#   6.0,
#   'Askale-Erzurum',
#   'A',
#   '2023/03/06 21:35:04',
#   'Stations Event'),
#  ('2023/03/06 20:34:58',
#   3.1,
#   'MLv',
#   '37.9074° N',
#   '36.3858° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/06 20:39:33',
#   'Stations Event'),
#  ('2023/03/06 17:29:56',
#   2.1,
#   'MLv',
#   '40.4205° N',
#   '25.9369° E',
#   11.0,
#   'Ege Denizi (Kuzey)',
#   'A',
#   '2023/03/06 17:32:20',
#   'Stations Event'),
#  ('2023/03/06 14:02:05',
#   3.3,
#   'MLv',
#   '37.9156° N',
#   '36.3885° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/06 14:04:53',
#   'Stations Event'),
#  ('2023/03/06 13:33:38',
#   3.2,
#   'MLv',
#   '37.5311° N',
#   '37.1942° E',
#   7.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/03/06 13:37:14',
#   'Stations Event'),
#  ('2023/03/06 12:09:37',
#   2.7,
#   'MLv',
#   '38.7112° N',
#   '35.3128° E',
#   0.0,
#   'Hacilar-Kayseri',
#   'A',
#   '2023/03/06 12:11:47',
#   'Stations Event'),
#  ('2023/03/06 11:02:58',
#   3.9,
#   'MLv',
#   '36.3300° N',
#   '35.9381° E',
#   9.0,
#   'iskenderun-Hatay',
#   'A',
#   '2023/03/06 11:53:17',
#   'Stations Event'),
#  ('2023/03/06 10:47:28',
#   2.8,
#   'MLv',
#   '39.0317° N',
#   '27.8641° E',
#   4.0,
#   'Akhisar-Manisa',
#   'A',
#   '2023/03/06 10:50:28',
#   'Stations Event'),
#  ('2023/03/06 08:14:16',
#   3.9,
#   'MLv',
#   '36.1011° N',
#   '36.2329° E',
#   6.0,
#   'Altinozu-Hatay',
#   'A',
#   '2023/03/06 08:18:08',
#   'Stations Event'),
#  ('2023/03/06 06:27:28',
#   3.6,
#   'MLv',
#   '38.0722° N',
#   '36.6714° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/06 06:30:43',
#   'Stations Event'),
#  ('2023/03/06 04:57:34',
#   3.9,
#   'MLv',
#   '38.9822° N',
#   '41.0953° E',
#   0.0,
#   'Solhan-Bingol',
#   'A',
#   '2023/03/06 05:00:35',
#   'Stations Event'),
#  ('2023/03/06 03:17:11',
#   2.4,
#   'MLv',
#   '37.0670° N',
#   '30.0925° E',
#   0.0,
#   'Korkuteli-Antalya',
#   'A',
#   '2023/03/06 03:20:06',
#   'Stations Event'),
#  ('2023/03/06 01:16:25',
#   2.8,
#   'MLv',
#   '37.5458° N',
#   '37.3151° E',
#   3.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/03/06 01:20:10',
#   'Stations Event'),
#  ('2023/03/06 00:48:50',
#   3.0,
#   'MLv',
#   '38.2709° N',
#   '36.3776° E',
#   6.0,
#   'Tufanbeyli-Adana',
#   'A',
#   '2023/03/06 00:51:41',
#   'Stations Event'),
#  ('2023/03/06 00:18:56',
#   3.4,
#   'MLv',
#   '37.9495° N',
#   '36.2759° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/06 00:22:47',
#   'Stations Event'),
#  ('2023/03/05 23:28:04',
#   2.9,
#   'MLv',
#   '38.6687° N',
#   '24.1169° E',
#   10.0,
#   'Aegean Sea',
#   'A',
#   '2023/03/05 23:49:35',
#   'Stations Event'),
#  ('2023/03/05 23:16:30',
#   3.4,
#   'MLv',
#   '36.4618° N',
#   '34.6088° E',
#   3.0,
#   'Turkey',
#   'A',
#   '2023/03/05 23:19:24',
#   'Stations Event'),
#  ('2023/03/05 22:25:16',
#   3.1,
#   'MLv',
#   '38.7543° N',
#   '35.2460° E',
#   0.0,
#   'incesu-Kayseri',
#   'A',
#   '2023/03/05 22:29:19',
#   'Stations Event'),
#  ('2023/03/05 21:50:13',
#   3.8,
#   'MLv',
#   '38.0099° N',
#   '36.7136° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/05 21:53:37',
#   'Stations Event'),
#  ('2023/03/05 20:49:46',
#   4.9,
#   'MLv',
#   '36.7453° N',
#   '36.1267° E',
#   7.0,
#   'Jordan/Syria Region',
#   'A',
#   '2023/03/05 21:40:00',
#   'Stations Event'),
#  ('2023/03/05 19:46:17',
#   1.8,
#   'MLv',
#   '40.4248° N',
#   '25.9683° E',
#   3.0,
#   'Ege Denizi (Kuzey)',
#   'M',
#   '2023/03/06 08:36:04',
#   'Stations Event'),
#  ('2023/03/05 19:07:15',
#   3.6,
#   'MLv',
#   '38.0795° N',
#   '36.5817° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/05 19:11:56',
#   'Stations Event'),
#  ('2023/03/05 16:03:21',
#   3.5,
#   'MLv',
#   '38.6069° N',
#   '40.8499° E',
#   0.0,
#   'Genc-Bingol',
#   'A',
#   '2023/03/05 16:06:14',
#   'Stations Event'),
#  ('2023/03/05 15:24:55',
#   2.1,
#   'MLv',
#   '40.4169° N',
#   '25.9332° E',
#   10.0,
#   'Ege Denizi (Kuzey)',
#   'A',
#   '2023/03/05 15:27:41',
#   'Stations Event'),
#  ('2023/03/05 14:36:06',
#   3.2,
#   'MLv',
#   '40.4317° N',
#   '25.9118° E',
#   12.0,
#   'Ege Denizi (Kuzey)',
#   'A',
#   '2023/03/05 15:25:56',
#   'Stations Event'),
#  ('2023/03/05 12:08:09',
#   3.8,
#   'MLv',
#   '38.1198° N',
#   '36.8362° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/05 12:11:14',
#   'Stations Event'),
#  ('2023/03/05 07:42:52',
#   3.1,
#   'MLv',
#   '39.1901° N',
#   '40.4315° E',
#   7.0,
#   'Adakli-Bingol',
#   'A',
#   '2023/03/05 07:45:54',
#   'Stations Event'),
#  ('2023/03/05 05:28:07',
#   3.2,
#   'MLv',
#   '40.7913° N',
#   '30.9622° E',
#   0.0,
#   'Golyaka-Duzce',
#   'A',
#   '2023/03/05 05:32:30',
#   'Stations Event'),
#  ('2023/03/05 05:03:32',
#   3.1,
#   'MLv',
#   '37.1613° N',
#   '36.9745° E',
#   5.0,
#   'Nurdagi-Gaziantep',
#   'A',
#   '2023/03/05 05:06:08',
#   'Stations Event'),
#  ('2023/03/05 04:46:55',
#   3.1,
#   'MLv',
#   '38.4778° N',
#   '39.6204° E',
#   0.0,
#   'Maden-Elazig',
#   'A',
#   '2023/03/05 04:49:39',
#   'Stations Event'),
#  ('2023/03/05 03:27:29',
#   2.5,
#   'MLv',
#   '37.9651° N',
#   '36.2439° E',
#   10.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/05 03:30:44',
#   'Stations Event'),
#  ('2023/03/05 01:30:15',
#   3.1,
#   'MLv',
#   '36.8738° N',
#   '36.5662° E',
#   1.0,
#   'islahiye-Gaziantep',
#   'A',
#   '2023/03/05 01:34:02',
#   'Stations Event'),
#  ('2023/03/05 00:19:47',
#   2.5,
#   'MLv',
#   '37.8625° N',
#   '36.6321° E',
#   2.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/03/05 00:23:41',
#   'Stations Event'),
#  ('2023/03/04 22:55:23',
#   3.9,
#   'MLv',
#   '44.9725° N',
#   '22.9999° E',
#   0.0,
#   'Romania',
#   'A',
#   '2023/03/04 23:14:04',
#   'Stations Event'),
#  ('2023/03/04 21:40:08',
#   2.3,
#   'MLv',
#   '37.3663° N',
#   '37.0844° E',
#   6.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/03/04 21:43:02',
#   'Stations Event'),
#  ('2023/03/04 20:59:41',
#   4.0,
#   'MLv',
#   '38.4677° N',
#   '40.3299° E',
#   0.0,
#   'Hani-Diyarbakir',
#   'A',
#   '2023/03/04 21:16:54',
#   'Stations Event'),
#  ('2023/03/04 20:48:41',
#   2.4,
#   'MLv',
#   '37.4652° N',
#   '37.0331° E',
#   9.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/03/04 20:51:14',
#   'Stations Event'),
#  ('2023/03/04 17:54:26',
#   3.4,
#   'MLv',
#   '38.0429° N',
#   '37.2665° E',
#   0.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/03/04 17:57:34',
#   'Stations Event'),
#  ('2023/03/04 17:16:37',
#   3.1,
#   'MLv',
#   '45.0916° N',
#   '25.4553° E',
#   26.0,
#   'Romania',
#   'A',
#   '2023/03/04 17:21:06',
#   'Stations Event'),
#  ('2023/03/04 15:52:40',
#   2.9,
#   'MLv',
#   '37.7582° N',
#   '38.5895° E',
#   14.0,
#   'Kahta-Adiyaman',
#   'A',
#   '2023/03/04 15:55:16',
#   'Stations Event'),
#  ('2023/03/04 14:14:47',
#   3.1,
#   'MLv',
#   '37.3288° N',
#   '32.4509° E',
#   0.0,
#   'Cumra-Konya',
#   'A',
#   '2023/03/04 14:17:19',
#   'Stations Event'),
#  ('2023/03/04 10:26:25',
#   3.9,
#   'MLv',
#   '37.4725° N',
#   '37.0148° E',
#   0.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/03/04 10:45:58',
#   'Stations Event'),
#  ('2023/03/04 09:42:56',
#   3.4,
#   'MLv',
#   '37.4432° N',
#   '37.6556° E',
#   33.0,
#   'Araban-Gaziantep',
#   'A',
#   '2023/03/04 09:46:15',
#   'Stations Event'),
#  ('2023/03/04 05:26:18',
#   3.9,
#   'MLv',
#   '38.8531° N',
#   '38.1390° E',
#   0.0,
#   'Hekimhan-Malatya',
#   'A',
#   '2023/03/04 05:29:33',
#   'Stations Event'),
#  ('2023/03/04 02:12:09',
#   2.7,
#   'MLv',
#   '37.3846° N',
#   '36.8829° E',
#   1.0,
#   'Turkoglu-Kahramanmaras',
#   'A',
#   '2023/03/04 02:15:52',
#   'Stations Event'),
#  ('2023/03/04 00:20:10',
#   4.1,
#   'MLv',
#   '38.1134° N',
#   '36.2494° E',
#   0.0,
#   'Saimbeyli-Adana',
#   'A',
#   '2023/03/04 00:43:02',
#   'Stations Event'),
#  ('2023/03/03 22:54:32',
#   3.0,
#   'MLv',
#   '36.9131° N',
#   '36.5524° E',
#   0.0,
#   'islahiye-Gaziantep',
#   'A',
#   '2023/03/03 22:58:10',
#   'Stations Event'),
#  ('2023/03/03 21:54:54',
#   2.6,
#   'MLv',
#   '38.8568° N',
#   '27.2845° E',
#   9.0,
#   'Merkez-Manisa',
#   'A',
#   '2023/03/03 21:58:10',
#   'Stations Event'),
#  ('2023/03/03 21:45:48',
#   2.9,
#   'MLv',
#   '37.0184° N',
#   '36.4471° E',
#   2.0,
#   'Merkez-Osmaniye',
#   'A',
#   '2023/03/03 21:48:54',
#   'Stations Event'),
#  ('2023/03/03 21:06:31',
#   2.4,
#   'MLv',
#   '40.3290° N',
#   '34.7333° E',
#   0.0,
#   'Merkez-Corum',
#   'A',
#   '2023/03/03 21:09:18',
#   'Stations Event'),
#  ('2023/03/03 19:20:32',
#   3.3,
#   'MLv',
#   '36.2439° N',
#   '36.1487° E',
#   9.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/03/03 19:25:45',
#   'Stations Event'),
#  ('2023/03/03 17:28:33',
#   2.0,
#   'MLv',
#   '39.3585° N',
#   '26.1676° E',
#   8.0,
#   'Turkey',
#   'A',
#   '2023/03/03 17:31:54',
#   'Stations Event'),
#  ('2023/03/03 14:52:35',
#   3.1,
#   'MLv',
#   '37.7829° N',
#   '37.9092° E',
#   0.0,
#   'Tut-Adiyaman',
#   'A',
#   '2023/03/03 14:55:54',
#   'Stations Event'),
#  ('2023/03/03 14:08:06',
#   2.6,
#   'MLv',
#   '38.7927° N',
#   '27.2791° E',
#   14.0,
#   'Merkez-Manisa',
#   'A',
#   '2023/03/03 14:10:03',
#   'Stations Event'),
#  ('2023/03/03 12:05:29',
#   3.6,
#   'MLv',
#   '36.1633° N',
#   '36.0242° E',
#   10.0,
#   'Samandag-Hatay',
#   'A',
#   '2023/03/03 12:09:08',
#   'Stations Event'),
#  ('2023/03/03 08:59:02',
#   2.8,
#   'MLv',
#   '37.7911° N',
#   '36.6119° E',
#   3.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/03/03 09:02:11',
#   'Stations Event'),
#  ('2023/03/03 07:13:06',
#   3.3,
#   'MLv',
#   '38.0978° N',
#   '37.8140° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/03/03 07:16:42',
#   'Stations Event'),
#  ('2023/03/03 04:59:25',
#   3.9,
#   'MLv',
#   '39.5709° N',
#   '35.8569° E',
#   10.0,
#   'Akdagmadeni-Yozgat',
#   'A',
#   '2023/03/03 05:03:41',
#   'Stations Event'),
#  ('2023/03/03 03:24:57',
#   2.5,
#   'MLv',
#   '37.8571° N',
#   '36.6449° E',
#   12.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/03/03 03:28:29',
#   'Stations Event'),
#  ('2023/03/03 01:56:38',
#   3.0,
#   'MLv',
#   '38.1537° N',
#   '38.0511° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/03/03 02:00:07',
#   'Stations Event'),
#  ('2023/03/03 01:21:45',
#   2.6,
#   'MLv',
#   '38.1921° N',
#   '38.5510° E',
#   2.0,
#   'Merkez-Malatya',
#   'A',
#   '2023/03/03 01:25:46',
#   'Stations Event'),
#  ('2023/03/02 23:34:09',
#   2.8,
#   'MLv',
#   '37.3004° N',
#   '37.0294° E',
#   8.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/03/02 23:38:03',
#   'Stations Event'),
#  ('2023/03/02 21:35:51',
#   3.0,
#   'MLv',
#   '38.9969° N',
#   '27.8659° E',
#   10.0,
#   'Akhisar-Manisa',
#   'A',
#   '2023/03/02 21:38:32',
#   'Stations Event'),
#  ('2023/03/02 21:03:45',
#   2.4,
#   'MLv',
#   '39.0960° N',
#   '26.8535° E',
#   2.0,
#   'Turkey',
#   'M',
#   '2023/03/03 05:40:08',
#   'Stations Event'),
#  ('2023/03/02 20:16:43',
#   3.9,
#   'MLv',
#   '38.0869° N',
#   '36.6422° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/02 20:20:42',
#   'Stations Event'),
#  ('2023/03/02 16:01:15',
#   2.5,
#   'MLv',
#   '37.4542° N',
#   '37.1246° E',
#   8.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/03/02 16:03:28',
#   'Stations Event'),
#  ('2023/03/02 15:23:29',
#   3.2,
#   'MLv',
#   '38.0219° N',
#   '36.4948° E',
#   4.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/02 15:26:27',
#   'Stations Event'),
#  ('2023/03/02 14:17:26',
#   2.4,
#   'MLv',
#   '37.3956° N',
#   '36.9379° E',
#   5.0,
#   'Turkoglu-Kahramanmaras',
#   'A',
#   '2023/03/02 14:19:56',
#   'Stations Event'),
#  ('2023/03/02 12:08:55',
#   2.5,
#   'MLv',
#   '37.0836° N',
#   '36.8066° E',
#   5.0,
#   'Nurdagi-Gaziantep',
#   'M',
#   '2023/03/03 05:43:11',
#   'Stations Event'),
#  ('2023/03/02 08:06:56',
#   2.7,
#   'MLv',
#   '37.1429° N',
#   '36.6156° E',
#   6.0,
#   'Bahce-Osmaniye',
#   'A',
#   '2023/03/02 08:11:32',
#   'Stations Event'),
#  ('2023/03/02 07:13:17',
#   2.3,
#   'MLv',
#   '37.8476° N',
#   '37.8418° E',
#   1.0,
#   'Golbasi-Adiyaman',
#   'M',
#   '2023/03/02 10:36:13',
#   'Stations Event'),
#  ('2023/03/02 06:29:48',
#   3.4,
#   'MLv',
#   '38.1216° N',
#   '38.5098° E',
#   0.0,
#   'Sincik-Adiyaman',
#   'A',
#   '2023/03/02 06:33:00',
#   'Stations Event'),
#  ('2023/03/02 06:05:54',
#   3.0,
#   'MLv',
#   '38.0804° N',
#   '37.1576° E',
#   7.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/03/02 06:08:47',
#   'Stations Event'),
#  ('2023/03/02 04:48:41',
#   3.3,
#   'MLv',
#   '39.1959° N',
#   '40.3021° E',
#   5.0,
#   'Kigi-Bingol',
#   'M',
#   '2023/03/02 06:04:55',
#   'Stations Event'),
#  ('2023/03/02 04:28:43',
#   2.8,
#   'MLv',
#   '38.1061° N',
#   '37.1429° E',
#   0.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/03/02 04:33:33',
#   'Stations Event'),
#  ('2023/03/02 02:19:41',
#   2.9,
#   'MLv',
#   '38.0594° N',
#   '38.4201° E',
#   0.0,
#   'Celikhan-Adiyaman',
#   'A',
#   '2023/03/02 02:22:42',
#   'Stations Event'),
#  ('2023/03/02 00:54:03',
#   3.2,
#   'MLv',
#   '38.1693° N',
#   '36.9864° E',
#   0.0,
#   'Afsin-Kahramanmaras',
#   'A',
#   '2023/03/02 00:58:00',
#   'Stations Event'),
#  ('2023/03/01 23:48:29',
#   2.3,
#   'MLv',
#   '37.3077° N',
#   '32.4188° E',
#   0.0,
#   'Bozkir-Konya',
#   'A',
#   '2023/03/01 23:50:58',
#   'Stations Event'),
#  ('2023/03/01 23:11:36',
#   2.6,
#   'MLv',
#   '36.2219° N',
#   '36.0535° E',
#   16.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/03/01 23:15:23',
#   'Stations Event'),
#  ('2023/03/01 21:30:29',
#   2.6,
#   'MLv',
#   '37.9477° N',
#   '37.6657° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/03/01 21:34:13',
#   'Stations Event'),
#  ('2023/03/01 19:46:08',
#   2.4,
#   'MLv',
#   '37.8326° N',
#   '36.6592° E',
#   3.0,
#   'Merkez-Kahramanmaras',
#   'M',
#   '2023/03/02 06:35:32',
#   'Stations Event'),
#  ('2023/03/01 18:25:45',
#   2.6,
#   'MLv',
#   '38.2561° N',
#   '37.2540° E',
#   4.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/03/01 18:28:32',
#   'Stations Event'),
#  ('2023/03/01 17:17:21',
#   3.0,
#   'MLv',
#   '38.7112° N',
#   '35.3146° E',
#   0.0,
#   'Hacilar-Kayseri',
#   'A',
#   '2023/03/01 17:20:25',
#   'Stations Event'),
#  ('2023/03/01 16:38:00',
#   4.3,
#   'MLv',
#   '37.2922° N',
#   '37.0505° E',
#   0.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/03/01 16:56:32',
#   'Stations Event'),
#  ('2023/03/01 14:27:12',
#   2.6,
#   'MLv',
#   '38.1747° N',
#   '37.0541° E',
#   0.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/03/01 14:29:49',
#   'Stations Event'),
#  ('2023/03/01 14:01:58',
#   3.0,
#   'MLv',
#   '38.7579° N',
#   '35.3522° E',
#   0.0,
#   'Melikgazi-Kayseri',
#   'A',
#   '2023/03/01 14:04:43',
#   'Stations Event'),
#  ('2023/03/01 13:18:32',
#   2.9,
#   'MLv',
#   '38.1500° N',
#   '36.7218° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/01 13:22:09',
#   'Stations Event'),
#  ('2023/03/01 12:42:51',
#   3.5,
#   'MLv',
#   '37.9587° N',
#   '37.6712° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/03/01 12:46:02',
#   'Stations Event'),
#  ('2023/03/01 11:00:20',
#   3.0,
#   'MLv',
#   '36.2457° N',
#   '36.1725° E',
#   13.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/03/01 11:03:53',
#   'Stations Event'),
#  ('2023/03/01 10:00:17',
#   3.3,
#   'MLv',
#   '36.8784° N',
#   '29.0048° E',
#   0.0,
#   'Dalaman-Mugla',
#   'A',
#   '2023/03/01 10:30:37',
#   'Stations Event'),
#  ('2023/03/01 08:55:53',
#   3.1,
#   'MLv',
#   '38.7360° N',
#   '35.3522° E',
#   0.0,
#   'Hacilar-Kayseri',
#   'A',
#   '2023/03/01 08:59:08',
#   'Stations Event'),
#  ('2023/03/01 06:40:51',
#   2.5,
#   'MLv',
#   '39.1534° N',
#   '29.0973° E',
#   6.0,
#   'Simav-Kutahya',
#   'A',
#   '2023/03/01 06:43:25',
#   'Stations Event'),
#  ('2023/03/01 05:41:39',
#   2.8,
#   'MLv',
#   '35.9824° N',
#   '31.2063° E',
#   5.0,
#   'Antalya Korfezi-AKDENIZ',
#   'M',
#   '2023/03/01 05:58:02',
#   'Stations Event'),
#  ('2023/03/02 07:29:24',
#   2.7,
#   'MLv',
#   '37.1320° N',
#   '36.7474° E',
#   12.0,
#   'Nurdagi-Gaziantep',
#   'A',
#   '2023/03/02 07:31:55',
#   'Stations Event'),
#  ('2023/03/02 06:47:33',
#   3.1,
#   'MLv',
#   '35.4990° N',
#   '32.3050° E',
#   13.0,
#   'Cyprus Region',
#   'M',
#   '2023/03/02 07:34:57',
#   'Stations Event'),
#  ('2023/03/02 06:29:48',
#   3.4,
#   'MLv',
#   '38.1216° N',
#   '38.5098° E',
#   0.0,
#   'Sincik-Adiyaman',
#   'A',
#   '2023/03/02 06:33:00',
#   'Stations Event'),
#  ('2023/03/02 06:14:47',
#   5.2,
#   'mb',
#   '43.5305° N',
#   '147.2541° E',
#   10.0,
#   'Kuril Islands',
#   'A',
#   '2023/03/02 06:43:49',
#   'Stations Event'),
#  ('2023/03/02 06:05:54',
#   3.0,
#   'MLv',
#   '38.0804° N',
#   '37.1576° E',
#   7.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/03/02 06:08:47',
#   'Stations Event'),
#  ('2023/03/02 05:57:28',
#   3.6,
#   'MLv',
#   '36.4069° N',
#   '36.2604° E',
#   0.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/03/02 06:02:06',
#   'Stations Event'),
#  ('2023/03/02 04:48:41',
#   3.3,
#   'MLv',
#   '39.1959° N',
#   '40.3021° E',
#   5.0,
#   'Kigi-Bingol',
#   'M',
#   '2023/03/02 06:04:55',
#   'Stations Event'),
#  ('2023/03/02 04:40:45',
#   5.8,
#   'mb',
#   '16.3600° N',
#   '94.1429° W',
#   101.0,
#   'Oaxaca, Mexico',
#   'A',
#   '2023/03/02 05:21:05',
#   'Stations Event'),
#  ('2023/03/02 04:28:43',
#   2.8,
#   'MLv',
#   '38.1061° N',
#   '37.1429° E',
#   0.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/03/02 04:33:33',
#   'Stations Event'),
#  ('2023/03/02 03:32:02',
#   3.4,
#   'MLv',
#   '40.9029° N',
#   '31.0302° E',
#   5.0,
#   'Cilimli-Duzce',
#   'M',
#   '2023/03/02 06:09:31',
#   'Stations Event'),
#  ('2023/03/02 02:19:41',
#   2.9,
#   'MLv',
#   '38.0594° N',
#   '38.4201° E',
#   0.0,
#   'Celikhan-Adiyaman',
#   'A',
#   '2023/03/02 02:22:42',
#   'Stations Event'),
#  ('2023/03/02 01:18:47',
#   3.8,
#   'MLv',
#   '38.0374° N',
#   '37.1146° E',
#   0.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/03/02 01:41:42',
#   'Stations Event'),
#  ('2023/03/02 00:54:03',
#   3.2,
#   'MLv',
#   '38.1693° N',
#   '36.9864° E',
#   0.0,
#   'Afsin-Kahramanmaras',
#   'A',
#   '2023/03/02 00:58:00',
#   'Stations Event'),
#  ('2023/03/02 00:16:11',
#   3.7,
#   'MLv',
#   '40.0443° N',
#   '38.6563° E',
#   0.0,
#   'Golova-Sivas',
#   'A',
#   '2023/03/02 00:22:10',
#   'Stations Event'),
#  ('2023/03/01 23:48:29',
#   2.3,
#   'MLv',
#   '37.3077° N',
#   '32.4188° E',
#   0.0,
#   'Bozkir-Konya',
#   'A',
#   '2023/03/01 23:50:58',
#   'Stations Event'),
#  ('2023/03/01 23:38:26',
#   1.9,
#   'MLv',
#   '38.1853° N',
#   '36.6046° E',
#   9.0,
#   'Goksun-Kahramanmaras',
#   'M',
#   '2023/03/02 06:13:24',
#   'Stations Event'),
#  ('2023/03/01 23:11:36',
#   2.6,
#   'MLv',
#   '36.2219° N',
#   '36.0535° E',
#   16.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/03/01 23:15:23',
#   'Stations Event'),
#  ('2023/03/01 23:05:23',
#   5.2,
#   'mb',
#   '1.6149° S',
#   '100.7994° E',
#   95.0,
#   'Southern Sumatra, Indonesia',
#   'A',
#   '2023/03/01 23:45:57',
#   'Stations Event'),
#  ('2023/03/01 22:52:15',
#   3.6,
#   'MLv',
#   '37.9953° N',
#   '36.4114° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/01 22:57:27',
#   'Stations Event'),
#  ('2023/03/01 22:31:58',
#   3.0,
#   'MLv',
#   '37.3114° N',
#   '36.9122° E',
#   9.0,
#   'Nurdagi-Gaziantep',
#   'A',
#   '2023/03/01 22:35:56',
#   'Stations Event'),
#  ('2023/03/01 21:30:29',
#   2.6,
#   'MLv',
#   '37.9477° N',
#   '37.6657° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/03/01 21:34:13',
#   'Stations Event'),
#  ('2023/03/01 20:53:25',
#   2.6,
#   'MLv',
#   '37.9576° N',
#   '36.3092° E',
#   7.0,
#   'Goksun-Kahramanmaras',
#   'M',
#   '2023/03/02 06:29:03',
#   'Stations Event'),
#  ('2023/03/01 19:46:08',
#   2.4,
#   'MLv',
#   '37.8326° N',
#   '36.6592° E',
#   3.0,
#   'Merkez-Kahramanmaras',
#   'M',
#   '2023/03/02 06:35:32',
#   'Stations Event'),
#  ('2023/03/01 19:28:08',
#   5.1,
#   'mb',
#   '14.0322° N',
#   '146.6745° E',
#   10.0,
#   'Mariana Islands',
#   'A',
#   '2023/03/01 20:21:55',
#   'Stations Event'),
#  ('2023/03/01 18:25:45',
#   2.6,
#   'MLv',
#   '38.2561° N',
#   '37.2540° E',
#   4.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/03/01 18:28:32',
#   'Stations Event'),
#  ('2023/03/01 18:04:14',
#   3.5,
#   'MLv',
#   '37.3764° N',
#   '36.8729° E',
#   0.0,
#   'Turkoglu-Kahramanmaras',
#   'A',
#   '2023/03/01 18:08:21',
#   'Stations Event'),
#  ('2023/03/01 17:17:21',
#   3.0,
#   'MLv',
#   '38.7112° N',
#   '35.3146° E',
#   0.0,
#   'Hacilar-Kayseri',
#   'A',
#   '2023/03/01 17:20:25',
#   'Stations Event'),
#  ('2023/03/01 16:55:17',
#   3.1,
#   'MLv',
#   '38.1390° N',
#   '36.6925° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/01 16:58:16',
#   'Stations Event'),
#  ('2023/03/01 16:38:00',
#   4.3,
#   'MLv',
#   '37.2922° N',
#   '37.0505° E',
#   0.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/03/01 16:56:32',
#   'Stations Event'),
#  ('2023/03/01 15:45:15',
#   3.0,
#   'MLv',
#   '37.9523° N',
#   '36.2640° E',
#   3.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/01 15:47:50',
#   'Stations Event'),
#  ('2023/03/01 14:27:12',
#   2.6,
#   'MLv',
#   '38.1747° N',
#   '37.0541° E',
#   0.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/03/01 14:29:49',
#   'Stations Event'),
#  ('2023/03/01 14:23:03',
#   2.9,
#   'MLv',
#   '36.7905° N',
#   '36.1624° E',
#   0.0,
#   'Jordan/Syria Region',
#   'A',
#   '2023/03/01 14:26:47',
#   'Stations Event'),
#  ('2023/03/01 14:01:58',
#   3.0,
#   'MLv',
#   '38.7579° N',
#   '35.3522° E',
#   0.0,
#   'Melikgazi-Kayseri',
#   'A',
#   '2023/03/01 14:04:43',
#   'Stations Event'),
#  ('2023/03/01 13:44:58',
#   2.3,
#   'MLv',
#   '36.9745° N',
#   '28.0206° E',
#   10.0,
#   'Gokova Korfezi-Ege Denizi',
#   'A',
#   '2023/03/01 13:47:46',
#   'Stations Event'),
#  ('2023/03/01 13:18:32',
#   2.9,
#   'MLv',
#   '38.1500° N',
#   '36.7218° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/01 13:22:09',
#   'Stations Event'),
#  ('2023/03/01 12:51:02',
#   3.3,
#   'MLv',
#   '38.0026° N',
#   '36.4151° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/01 12:54:02',
#   'Stations Event'),
#  ('2023/03/01 12:42:51',
#   3.5,
#   'MLv',
#   '37.9587° N',
#   '37.6712° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/03/01 12:46:02',
#   'Stations Event'),
#  ('2023/03/01 11:06:57',
#   3.8,
#   'MLv',
#   '38.0634° N',
#   '37.6716° E',
#   10.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/03/01 11:11:07',
#   'Stations Event'),
#  ('2023/03/01 11:00:20',
#   3.0,
#   'MLv',
#   '36.2457° N',
#   '36.1725° E',
#   13.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/03/01 11:03:53',
#   'Stations Event'),
#  ('2023/03/01 10:52:35',
#   4.1,
#   'MLv',
#   '41.3141° N',
#   '43.9691° E',
#   3.0,
#   'Georgia Armenia Turkey Border Reg.',
#   'A',
#   '2023/03/01 10:56:45',
#   'Stations Event'),
#  ('2023/03/01 10:00:17',
#   3.3,
#   'MLv',
#   '36.8784° N',
#   '29.0048° E',
#   0.0,
#   'Dalaman-Mugla',
#   'A',
#   '2023/03/01 10:30:37',
#   'Stations Event'),
#  ('2023/03/01 09:32:09',
#   2.0,
#   'MLv',
#   '37.3055° N',
#   '31.8835° E',
#   5.0,
#   'Seydisehir-Konya',
#   'M',
#   '2023/03/01 13:33:36',
#   'Stations Event'),
#  ('2023/03/01 08:55:53',
#   3.1,
#   'MLv',
#   '38.7360° N',
#   '35.3522° E',
#   0.0,
#   'Hacilar-Kayseri',
#   'A',
#   '2023/03/01 08:59:08',
#   'Stations Event'),
#  ('2023/03/01 07:20:21',
#   4.9,
#   'MLv',
#   '36.3016° N',
#   '36.0383° E',
#   5.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/03/01 08:01:29',
#   'Stations Event'),
#  ('2023/03/01 06:40:51',
#   2.5,
#   'MLv',
#   '39.1534° N',
#   '29.0973° E',
#   6.0,
#   'Simav-Kutahya',
#   'A',
#   '2023/03/01 06:43:25',
#   'Stations Event'),
#  ('2023/03/01 06:32:07',
#   3.0,
#   'MLv',
#   '37.1503° N',
#   '36.6595° E',
#   4.0,
#   'islahiye-Gaziantep',
#   'A',
#   '2023/03/01 06:35:24',
#   'Stations Event'),
#  ('2023/03/01 05:41:39',
#   2.8,
#   'MLv',
#   '35.9824° N',
#   '31.2063° E',
#   5.0,
#   'Antalya Korfezi-AKDENIZ',
#   'M',
#   '2023/03/01 05:58:02',
#   'Stations Event'),
#  ('2023/03/01 05:36:15',
#   6.1,
#   'Mwp',
#   '4.8343° S',
#   '149.4758° E',
#   589.0,
#   'Bismarck Sea',
#   'A',
#   '2023/03/01 06:24:27',
#   'Stations Event'),
#  ('2023/03/01 04:15:30',
#   4.2,
#   'MLv',
#   '37.8122° N',
#   '37.8653° E',
#   0.0,
#   'Tut-Adiyaman',
#   'A',
#   '2023/03/01 04:33:24',
#   'Stations Event'),
#  ('2023/03/01 04:06:08',
#   2.8,
#   'MLv',
#   '40.5267° N',
#   '34.5172° E',
#   0.0,
#   'Ugurludag-Corum',
#   'A',
#   '2023/03/01 04:09:04',
#   'Stations Event'),
#  ('2023/03/01 03:37:05',
#   3.1,
#   'MLv',
#   '38.3011° N',
#   '36.5250° E',
#   0.0,
#   'Sariz-Kayseri',
#   'A',
#   '2023/03/01 03:40:03',
#   'Stations Event'),
#  ('2023/03/01 03:24:53',
#   3.0,
#   'MLv',
#   '37.8992° N',
#   '36.5369° E',
#   10.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/03/01 03:27:32',
#   'Stations Event'),
#  ('2023/03/01 02:41:30',
#   2.8,
#   'MLv',
#   '36.2609° N',
#   '36.2677° E',
#   3.0,
#   'Merkez-Hatay',
#   'M',
#   '2023/03/01 06:33:38',
#   'Stations Event'),
#  ('2023/03/01 02:23:22',
#   4.3,
#   'MLv',
#   '38.0045° N',
#   '37.1109° E',
#   0.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/03/01 02:53:24',
#   'Stations Event'),
#  ('2023/03/01 01:44:25',
#   3.2,
#   'MLv',
#   '37.9120° N',
#   '36.3885° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/03/01 01:47:23',
#   'Stations Event'),
#  ('2023/03/01 01:04:11',
#   2.9,
#   'MLv',
#   '38.2141° N',
#   '37.7707° E',
#   1.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/03/01 01:06:49',
#   'Stations Event'),
#  ('2023/02/28 23:32:11',
#   3.9,
#   'MLv',
#   '37.3334° N',
#   '37.0770° E',
#   8.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/28 23:50:36',
#   'Stations Event'),
#  ('2023/02/28 23:25:52',
#   2.6,
#   'MLv',
#   '37.1063° N',
#   '35.8722° E',
#   2.0,
#   'Ceyhan-Adana',
#   'A',
#   '2023/02/28 23:29:30',
#   'Stations Event'),
#  ('2023/02/28 23:14:04',
#   2.8,
#   'MLv',
#   '36.2457° N',
#   '35.9271° E',
#   3.0,
#   'Samandag-Hatay',
#   'A',
#   '2023/02/28 23:17:27',
#   'Stations Event'),
#  ('2023/02/28 22:56:16',
#   2.6,
#   'MLv',
#   '37.1122° N',
#   '30.3257° E',
#   81.0,
#   'Korkuteli-Antalya',
#   'A',
#   '2023/02/28 23:00:09',
#   'Stations Event'),
#  ('2023/02/28 21:33:32',
#   3.1,
#   'MLv',
#   '37.3727° N',
#   '36.8784° E',
#   0.0,
#   'Turkoglu-Kahramanmaras',
#   'A',
#   '2023/02/28 21:38:25',
#   'Stations Event'),
#  ('2023/02/28 21:31:43',
#   2.9,
#   'MLv',
#   '36.9203° N',
#   '35.9618° E',
#   41.0,
#   'Ceyhan-Adana',
#   'A',
#   '2023/02/28 21:35:23',
#   'Stations Event'),
#  ('2023/02/28 21:17:45',
#   3.7,
#   'MLv',
#   '38.0466° N',
#   '36.4426° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/28 21:21:56',
#   'Stations Event'),
#  ('2023/02/28 21:06:20',
#   3.1,
#   'MLv',
#   '38.2480° N',
#   '37.1512° E',
#   0.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/02/28 21:10:26',
#   'Stations Event'),
#  ('2023/02/28 21:00:13',
#   2.5,
#   'MLv',
#   '37.0990° N',
#   '36.9708° E',
#   5.0,
#   'Nurdagi-Gaziantep',
#   'A',
#   '2023/02/28 21:03:46',
#   'Stations Event'),
#  ('2023/02/28 18:51:45',
#   3.8,
#   'MLv',
#   '37.3187° N',
#   '37.0880° E',
#   6.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/28 19:07:48',
#   'Stations Event'),
#  ('2023/02/28 18:29:15',
#   2.9,
#   'MLv',
#   '38.0713° N',
#   '38.4521° E',
#   3.0,
#   'Sincik-Adiyaman',
#   'A',
#   '2023/02/28 18:32:47',
#   'Stations Event'),
#  ('2023/02/28 18:21:27',
#   3.0,
#   'MLv',
#   '37.7948° N',
#   '36.6010° E',
#   10.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/28 18:24:04',
#   'Stations Event'),
#  ('2023/02/28 18:06:24',
#   2.9,
#   'MLv',
#   '38.0731° N',
#   '36.6705° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/28 18:09:09',
#   'Stations Event'),
#  ('2023/02/28 17:43:45',
#   4.0,
#   'MLv',
#   '41.0120° N',
#   '19.7571° E',
#   4.0,
#   'Albania',
#   'A',
#   '2023/02/28 17:48:34',
#   'Stations Event'),
#  ('2023/02/28 17:05:51',
#   3.4,
#   'MLv',
#   '36.3666° N',
#   '36.0150° E',
#   0.0,
#   'iskenderun-Hatay',
#   'A',
#   '2023/02/28 17:09:36',
#   'Stations Event'),
#  ('2023/02/28 16:59:10',
#   4.0,
#   'MLv',
#   '38.7717° N',
#   '35.4007° E',
#   0.0,
#   'Kocasinan-Kayseri',
#   'A',
#   '2023/02/28 17:23:05',
#   'Stations Event'),
#  ('2023/02/28 15:56:40',
#   4.1,
#   'MLv',
#   '36.0059° N',
#   '22.0605° E',
#   17.0,
#   'Southern Greece',
#   'A',
#   '2023/02/28 16:01:20',
#   'Stations Event'),
#  ('2023/02/28 15:52:10',
#   3.4,
#   'MLv',
#   '38.0109° N',
#   '37.7985° E',
#   4.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/28 15:55:34',
#   'Stations Event'),
#  ('2023/02/28 15:47:23',
#   2.9,
#   'MLv',
#   '37.8900° N',
#   '36.6522° E',
#   11.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/28 15:49:57',
#   'Stations Event'),
#  ('2023/02/28 15:16:39',
#   4.4,
#   'MLv',
#   '38.7936° N',
#   '35.3531° E',
#   0.0,
#   'Kocasinan-Kayseri',
#   'A',
#   '2023/02/28 15:36:55',
#   'Stations Event'),
#  ('2023/02/28 14:49:17',
#   3.9,
#   'MLv',
#   '37.8241° N',
#   '36.6486° E',
#   0.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/28 14:53:25',
#   'Stations Event'),
#  ('2023/02/28 14:39:55',
#   4.5,
#   'MLv',
#   '37.7875° N',
#   '36.6742° E',
#   4.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/28 15:01:37',
#   'Stations Event'),
#  ('2023/02/28 13:21:49',
#   2.2,
#   'MLv',
#   '38.9081° N',
#   '27.8741° E',
#   5.0,
#   'Akhisar-Manisa',
#   'A',
#   '2023/02/28 13:24:11',
#   'Stations Event'),
#  ('2023/02/28 13:15:06',
#   3.3,
#   'MLv',
#   '38.2089° N',
#   '38.7351° E',
#   5.0,
#   'Puturge-Malatya',
#   'A',
#   '2023/02/28 13:19:08',
#   'Stations Event'),
#  ('2023/02/28 12:42:16',
#   4.0,
#   'MLv',
#   '37.3260° N',
#   '36.2567° E',
#   0.0,
#   'Kadirli-Osmaniye',
#   'A',
#   '2023/02/28 13:01:18',
#   'Stations Event'),
#  ('2023/02/28 11:12:11',
#   5.1,
#   'mb',
#   '32.9888° N',
#   '141.7932° E',
#   10.0,
#   'Southeast of Honshu, Japan',
#   'A',
#   '2023/02/28 12:03:28',
#   'Stations Event'),
#  ('2023/02/28 10:23:38',
#   3.7,
#   'MLv',
#   '37.2903° N',
#   '37.1072° E',
#   0.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/28 10:27:33',
#   'Stations Event'),
#  ('2023/02/28 10:18:00',
#   2.4,
#   'MLv',
#   '37.9510° N',
#   '36.6604° E',
#   7.0,
#   'Merkez-Kahramanmaras',
#   'M',
#   '2023/02/28 12:48:28',
#   'Stations Event'),
#  ('2023/02/28 10:09:22',
#   2.7,
#   'MLv',
#   '38.7167° N',
#   '35.3201° E',
#   0.0,
#   'Hacilar-Kayseri',
#   'A',
#   '2023/02/28 10:12:58',
#   'Stations Event'),
#  ('2023/02/28 10:07:00',
#   2.9,
#   'MLv',
#   '38.1848° N',
#   '37.8918° E',
#   79.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/28 10:10:27',
#   'Stations Event'),
#  ('2023/02/28 09:55:32',
#   2.8,
#   'MLv',
#   '37.9843° N',
#   '36.3382° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/28 10:00:03',
#   'Stations Event'),
#  ('2023/02/28 09:34:19',
#   3.5,
#   'MLv',
#   '37.2894° N',
#   '37.1246° E',
#   0.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/28 09:39:11',
#   'Stations Event'),
#  ('2023/02/28 08:59:18',
#   2.8,
#   'MLv',
#   '38.0980° N',
#   '37.8410° E',
#   5.0,
#   'Dogansehir-Malatya',
#   'M',
#   '2023/02/28 09:39:54',
#   'Stations Event'),
#  ('2023/02/28 08:18:22',
#   3.6,
#   'MLv',
#   '38.1253° N',
#   '38.5226° E',
#   0.0,
#   'Sincik-Adiyaman',
#   'A',
#   '2023/02/28 08:21:34',
#   'Stations Event'),
#  ('2023/02/28 07:30:53',
#   2.8,
#   'MLv',
#   '37.5861° N',
#   '31.6534° E',
#   0.0,
#   'Beysehir-Konya',
#   'A',
#   '2023/02/28 07:33:28',
#   'Stations Event'),
#  ('2023/02/28 06:57:34',
#   3.5,
#   'MLv',
#   '38.0878° N',
#   '37.4908° E',
#   1.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/02/28 07:00:50',
#   'Stations Event'),
#  ('2023/02/28 06:38:14',
#   4.0,
#   'MLv',
#   '38.0612° N',
#   '37.8030° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/28 06:42:15',
#   'Stations Event'),
#  ('2023/02/28 06:26:49',
#   3.6,
#   'MLv',
#   '38.1061° N',
#   '37.4506° E',
#   7.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/02/28 06:30:10',
#   'Stations Event'),
#  ('2023/02/28 05:56:28',
#   3.0,
#   'MLv',
#   '37.9516° N',
#   '37.4771° E',
#   5.0,
#   'Nurhak-Kahramanmaras',
#   'M',
#   '2023/02/28 06:12:06',
#   'Stations Event'),
#  ('2023/02/28 04:29:16',
#   3.6,
#   'MLv',
#   '38.0026° N',
#   '36.4536° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/28 04:33:16',
#   'Stations Event'),
#  ('2023/02/28 04:14:07',
#   2.8,
#   'MLv',
#   '37.4501° N',
#   '37.1711° E',
#   5.0,
#   'Pazarcik-Kahramanmaras',
#   'M',
#   '2023/02/28 06:09:29',
#   'Stations Event'),
#  ('2023/02/28 04:00:22',
#   2.9,
#   'MLv',
#   '36.8134° N',
#   '36.5057° E',
#   7.0,
#   'Hassa-Hatay',
#   'A',
#   '2023/02/28 04:04:06',
#   'Stations Event'),
#  ('2023/02/28 03:55:21',
#   3.4,
#   'MLv',
#   '45.0348° N',
#   '23.0475° E',
#   10.0,
#   'Romania',
#   'A',
#   '2023/02/28 03:59:56',
#   'Stations Event'),
#  ('2023/02/28 03:41:41',
#   2.7,
#   'MLv',
#   '38.0255° N',
#   '36.8463° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/28 03:45:20',
#   'Stations Event'),
#  ('2023/02/28 03:03:46',
#   3.1,
#   'MLv',
#   '37.9779° N',
#   '34.0338° E',
#   5.0,
#   'Bor-Nigde',
#   'A',
#   '2023/02/28 03:22:00',
#   'Stations Event'),
#  ('2023/02/28 02:58:54',
#   2.9,
#   'MLv',
#   '37.3553° N',
#   '36.7255° E',
#   6.0,
#   'Turkoglu-Kahramanmaras',
#   'A',
#   '2023/02/28 03:02:41',
#   'Stations Event'),
#  ('2023/02/28 02:18:58',
#   4.2,
#   'MLv',
#   '38.2480° N',
#   '38.2883° E',
#   0.0,
#   'Yesilyurt-Malatya',
#   'A',
#   '2023/02/28 02:34:50',
#   'Stations Event'),
#  ('2023/02/28 02:13:33',
#   3.0,
#   'MLv',
#   '38.0914° N',
#   '37.0477° E',
#   3.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/02/28 02:17:37',
#   'Stations Event'),
#  ('2023/02/28 02:11:43',
#   2.9,
#   'MLv',
#   '36.0333° N',
#   '35.9198° E',
#   11.0,
#   'Turkey',
#   'A',
#   '2023/02/28 02:15:20',
#   'Stations Event'),
#  ('2023/02/28 02:10:03',
#   2.4,
#   'MLv',
#   '37.4908° N',
#   '37.1942° E',
#   9.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/28 02:12:10',
#   'Stations Event'),
#  ('2023/02/28 00:45:41',
#   3.6,
#   'MLv',
#   '38.1747° N',
#   '38.0576° E',
#   0.0,
#   'Yesilyurt-Malatya',
#   'A',
#   '2023/02/28 00:50:06',
#   'Stations Event'),
#  ('2023/02/28 00:36:09',
#   2.7,
#   'MLv',
#   '37.3846° N',
#   '36.9196° E',
#   0.0,
#   'Turkoglu-Kahramanmaras',
#   'A',
#   '2023/02/28 00:40:08',
#   'Stations Event'),
#  ('2023/02/28 00:17:35',
#   3.3,
#   'MLv',
#   '39.1425° N',
#   '40.4315° E',
#   0.0,
#   'Adakli-Bingol',
#   'A',
#   '2023/02/28 00:20:38',
#   'Stations Event'),
#  ('2023/02/28 00:13:39',
#   2.8,
#   'MLv',
#   '37.9999° N',
#   '36.5240° E',
#   5.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/28 00:16:21',
#   'Stations Event'),
#  ('2023/02/27 23:27:15',
#   2.8,
#   'MLv',
#   '38.5593° N',
#   '29.0341° E',
#   0.0,
#   'Esme-Usak',
#   'A',
#   '2023/02/27 23:30:57',
#   'Stations Event'),
#  ('2023/02/27 23:17:10',
#   2.6,
#   'MLv',
#   '37.2308° N',
#   '36.9452° E',
#   6.0,
#   'Nurdagi-Gaziantep',
#   'A',
#   '2023/02/27 23:19:53',
#   'Stations Event'),
#  ('2023/02/27 23:13:32',
#   2.4,
#   'MLv',
#   '38.2188° N',
#   '38.6522° E',
#   6.0,
#   'Puturge-Malatya',
#   'M',
#   '2023/02/28 05:59:18',
#   'Stations Event'),
#  ('2023/02/27 22:58:43',
#   2.4,
#   'MLv',
#   '37.1283° N',
#   '36.7365° E',
#   2.0,
#   'Nurdagi-Gaziantep',
#   'A',
#   '2023/02/27 23:01:11',
#   'Stations Event'),
#  ('2023/02/27 22:46:40',
#   2.9,
#   'MLv',
#   '37.9092° N',
#   '37.8470° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/27 22:50:35',
#   'Stations Event'),
#  ('2023/02/27 22:23:21',
#   2.9,
#   'MLv',
#   '39.3723° N',
#   '26.2509° E',
#   11.0,
#   'Midilli Adasi-Ege Denizi',
#   'A',
#   '2023/02/27 22:26:30',
#   'Stations Event'),
#  ('2023/02/27 20:59:26',
#   2.8,
#   'MLv',
#   '37.6996° N',
#   '36.1029° E',
#   3.0,
#   'Kozan-Adana',
#   'A',
#   '2023/02/27 21:02:13',
#   'Stations Event'),
#  ('2023/02/27 20:03:33',
#   2.8,
#   'MLv',
#   '38.0740° N',
#   '36.5359° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/27 20:06:54',
#   'Stations Event'),
#  ('2023/02/27 19:43:32',
#   3.6,
#   'MLv',
#   '38.0804° N',
#   '36.9489° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/27 19:47:40',
#   'Stations Event'),
#  ('2023/02/27 19:19:57',
#   2.6,
#   'MLv',
#   '40.2713° N',
#   '33.5513° E',
#   0.0,
#   'Kalecik-Ankara',
#   'A',
#   '2023/02/27 19:23:57',
#   'Stations Event'),
#  ('2023/02/27 19:12:01',
#   3.9,
#   'MLv',
#   '37.8360° N',
#   '36.6678° E',
#   0.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/27 19:40:44',
#   'Stations Event'),
#  ('2023/02/27 18:46:10',
#   5.3,
#   'mb',
#   '12.6330° N',
#   '87.7937° W',
#   100.0,
#   'Near Coast of Nicaragua',
#   'A',
#   '2023/02/27 21:09:28',
#   'Stations Event'),
#  ('2023/02/27 18:44:46',
#   2.6,
#   'MLv',
#   '37.7142° N',
#   '29.1925° E',
#   7.0,
#   'Merkez-Denizli',
#   'A',
#   '2023/02/27 18:46:58',
#   'Stations Event'),
#  ('2023/02/27 18:38:16',
#   2.9,
#   'MLv',
#   '38.0695° N',
#   '36.6339° E',
#   4.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/27 18:40:52',
#   'Stations Event'),
#  ('2023/02/27 18:22:20',
#   4.1,
#   'MLv',
#   '38.6417° N',
#   '26.6630° E',
#   7.0,
#   'Aegean Sea',
#   'A',
#   '2023/02/27 19:18:30',
#   'Stations Event'),
#  ('2023/02/27 17:34:59',
#   3.3,
#   'MLv',
#   '38.1747° N',
#   '38.0246° E',
#   0.0,
#   'Yesilyurt-Malatya',
#   'A',
#   '2023/02/27 17:39:18',
#   'Stations Event'),
#  ('2023/02/27 16:30:12',
#   2.9,
#   'MLv',
#   '37.8525° N',
#   '36.3144° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/27 16:33:33',
#   'Stations Event'),
#  ('2023/02/27 16:16:46',
#   4.1,
#   'MLv',
#   '37.8964° N',
#   '37.6254° E',
#   0.0,
#   'Golbasi-Adiyaman',
#   'A',
#   '2023/02/27 16:38:54',
#   'Stations Event'),
#  ('2023/02/27 15:32:28',
#   3.5,
#   'MLv',
#   '38.7515° N',
#   '40.0296° E',
#   0.0,
#   'Kovancilar-Elazig',
#   'A',
#   '2023/02/27 15:34:54',
#   'Stations Event'),
#  ('2023/02/27 15:25:56',
#   2.9,
#   'MLv',
#   '38.0658° N',
#   '36.5497° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/27 15:29:08',
#   'Stations Event'),
#  ('2023/02/27 15:12:43',
#   2.7,
#   'MLv',
#   '38.2143° N',
#   '37.7347° E',
#   3.0,
#   'Dogansehir-Malatya',
#   'M',
#   '2023/02/28 05:56:28',
#   'Stations Event'),
#  ('2023/02/27 15:06:35',
#   3.4,
#   'MLv',
#   '37.9752° N',
#   '38.1894° E',
#   0.0,
#   'Merkez-Adiyaman',
#   'A',
#   '2023/02/27 15:11:30',
#   'Stations Event'),
#  ('2023/02/27 13:52:27',
#   3.8,
#   'MLv',
#   '37.9230° N',
#   '37.5897° E',
#   0.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/02/27 13:56:42',
#   'Stations Event'),
#  ('2023/02/27 13:36:43',
#   3.3,
#   'MLv',
#   '38.0170° N',
#   '37.5176° E',
#   3.0,
#   'Nurhak-Kahramanmaras',
#   'M',
#   '2023/02/27 13:47:02',
#   'Stations Event'),
#  ('2023/02/27 13:34:17',
#   3.0,
#   'MLv',
#   '36.2219° N',
#   '36.1560° E',
#   11.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/02/27 13:37:52',
#   'Stations Event'),
#  ('2023/02/27 13:04:55',
#   3.2,
#   'MLv',
#   '36.1304° N',
#   '36.2915° E',
#   9.0,
#   'Altinozu-Hatay',
#   'A',
#   '2023/02/27 13:08:53',
#   'Stations Event'),
#  ('2023/02/27 13:02:37',
#   4.4,
#   'MLv',
#   '44.7070° N',
#   '34.5117° E',
#   39.0,
#   'Crimea Region, Ukraine',
#   'A',
#   '2023/02/27 13:07:52',
#   'Stations Event'),
#  ('2023/02/27 12:45:55',
#   3.4,
#   'MLv',
#   '36.2555° N',
#   '36.1891° E',
#   20.0,
#   'Merkez-Hatay',
#   'M',
#   '2023/02/27 13:10:53',
#   'Stations Event'),
#  ('2023/02/27 12:36:22',
#   3.1,
#   'MLv',
#   '38.1874° N',
#   '38.6475° E',
#   5.0,
#   'Puturge-Malatya',
#   'M',
#   '2023/02/27 12:45:17',
#   'Stations Event'),
#  ('2023/02/27 11:50:59',
#   2.8,
#   'MLv',
#   '38.2013° N',
#   '37.8850° E',
#   1.0,
#   'Dogansehir-Malatya',
#   'M',
#   '2023/02/27 12:26:14',
#   'Stations Event'),
#  ('2023/02/27 10:21:19',
#   2.9,
#   'MLv',
#   '37.8204° N',
#   '36.6083° E',
#   7.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/27 10:25:08',
#   'Stations Event'),
#  ('2023/02/27 09:43:55',
#   3.6,
#   'MLv',
#   '38.0722° N',
#   '37.2885° E',
#   0.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/02/27 09:48:03',
#   'Stations Event'),
#  ('2023/02/27 09:36:42',
#   3.1,
#   'MLv',
#   '37.9230° N',
#   '36.3153° E',
#   5.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/27 09:38:58',
#   'Stations Event'),
#  ('2023/02/27 09:04:52',
#   5.6,
#   'MLv',
#   '38.2124° N',
#   '38.4124° E',
#   83.0,
#   'Yesilyurt-Malatya',
#   'A',
#   '2023/02/27 09:43:03',
#   'Stations Event'),
#  ('2023/02/27 08:16:03',
#   3.0,
#   'MLv',
#   '37.7580° N',
#   '37.7456° E',
#   5.0,
#   'Besni-Adiyaman',
#   'M',
#   '2023/02/27 08:53:02',
#   'Stations Event'),
#  ('2023/02/27 07:04:40',
#   2.9,
#   'MLv',
#   '38.1390° N',
#   '36.8756° E',
#   0.0,
#   'Afsin-Kahramanmaras',
#   'A',
#   '2023/02/27 07:09:23',
#   'Stations Event'),
#  ('2023/02/27 06:52:31',
#   3.0,
#   'MLv',
#   '36.1047° N',
#   '35.7019° E',
#   0.0,
#   'Turkey',
#   'A',
#   '2023/02/27 06:55:58',
#   'Stations Event'),
#  ('2023/02/27 06:41:00',
#   5.3,
#   'mb',
#   '20.5957° S',
#   '178.4221° W',
#   551.0,
#   'Fiji Islands Region',
#   'A',
#   '2023/02/27 08:55:01',
#   'Stations Event'),
#  ('2023/02/27 06:28:36',
#   4.7,
#   'MLv',
#   '37.8900° N',
#   '38.1720° E',
#   105.0,
#   'Merkez-Adiyaman',
#   'A',
#   '2023/02/27 06:32:42',
#   'Stations Event'),
#  ('2023/02/27 06:19:48',
#   4.5,
#   'MLv',
#   '37.9999° N',
#   '37.1027° E',
#   0.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/02/27 06:24:22',
#   'Stations Event'),
#  ('2023/02/27 05:11:37',
#   3.3,
#   'MLv',
#   '38.1775° N',
#   '38.1262° E',
#   10.0,
#   'Yesilyurt-Malatya',
#   'A',
#   '2023/02/27 05:13:47',
#   'Stations Event'),
#  ('2023/02/27 04:47:47',
#   3.6,
#   'MLv',
#   '38.1161° N',
#   '37.2134° E',
#   0.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/02/27 04:51:36',
#   'Stations Event'),
#  ('2023/02/27 04:43:16',
#   2.9,
#   'MLv',
#   '37.5897° N',
#   '37.3077° E',
#   1.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/27 04:48:03',
#   'Stations Event'),
#  ('2023/02/27 02:51:24',
#   5.3,
#   'MLv',
#   '37.7519° N',
#   '37.5607° E',
#   83.0,
#   'Golbasi-Adiyaman',
#   'A',
#   '2023/02/27 03:21:22',
#   'Stations Event'),
#  ('2023/02/27 02:15:16',
#   3.1,
#   'MLv',
#   '36.0370° N',
#   '35.9161° E',
#   12.0,
#   'Turkey',
#   'A',
#   '2023/02/27 02:18:48',
#   'Stations Event'),
#  ('2023/02/27 01:26:03',
#   5.3,
#   'mb',
#   '1.5639° S',
#   '120.2471° E',
#   10.0,
#   'Sulawesi, Indonesia',
#   'A',
#   '2023/02/27 04:01:48',
#   'Stations Event'),
#  ('2023/02/27 00:27:49',
#   3.1,
#   'MLv',
#   '36.0388° N',
#   '36.0095° E',
#   11.0,
#   'Yayladagi-Hatay',
#   'A',
#   '2023/02/27 00:32:12',
#   'Stations Event'),
#  ('2023/02/27 00:23:32',
#   3.2,
#   'MLv',
#   '37.8717° N',
#   '36.6852° E',
#   0.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/27 00:27:17',
#   'Stations Event'),
#  ('2023/02/26 23:45:17',
#   3.6,
#   'MLv',
#   '35.9674° N',
#   '35.9161° E',
#   2.0,
#   'Jordan/Syria Region',
#   'A',
#   '2023/02/27 00:13:52',
#   'Stations Event'),
#  ('2023/02/26 22:54:56',
#   3.1,
#   'MLv',
#   '38.2599° N',
#   '37.1539° E',
#   0.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/02/26 22:57:50',
#   'Stations Event'),
#  ('2023/02/26 22:32:57',
#   2.9,
#   'MLv',
#   '38.2654° N',
#   '38.7561° E',
#   9.0,
#   'Puturge-Malatya',
#   'A',
#   '2023/02/26 22:36:53',
#   'Stations Event'),
#  ('2023/02/26 22:04:58',
#   3.0,
#   'MLv',
#   '38.7187° N',
#   '37.4862° E',
#   5.0,
#   'Darende-Malatya',
#   'M',
#   '2023/02/27 05:58:14',
#   'Stations Event'),
#  ('2023/02/26 21:03:04',
#   2.7,
#   'MLv',
#   '37.8918° N',
#   '36.6541° E',
#   9.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/26 21:05:43',
#   'Stations Event'),
#  ('2023/02/26 20:33:14',
#   3.9,
#   'MLv',
#   '37.9953° N',
#   '37.2940° E',
#   0.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/02/26 20:56:40',
#   'Stations Event'),
#  ('2023/02/26 20:13:12',
#   3.5,
#   'MLv',
#   '38.1921° N',
#   '38.6975° E',
#   0.0,
#   'Puturge-Malatya',
#   'A',
#   '2023/02/26 20:16:20',
#   'Stations Event'),
#  ('2023/02/26 18:28:41',
#   2.7,
#   'MLv',
#   '38.0841° N',
#   '36.7511° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/26 18:32:17',
#   'Stations Event'),
#  ('2023/02/26 18:03:52',
#   2.9,
#   'MLv',
#   '38.1134° N',
#   '36.7841° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/26 18:06:20',
#   'Stations Event'),
#  ('2023/02/26 17:25:28',
#   3.4,
#   'MLv',
#   '37.3260° N',
#   '37.0294° E',
#   0.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/26 17:29:25',
#   'Stations Event'),
#  ('2023/02/26 14:16:30',
#   3.0,
#   'MLv',
#   '38.0603° N',
#   '36.6248° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/26 14:19:09',
#   'Stations Event'),
#  ('2023/02/26 12:32:01',
#   3.6,
#   'MLv',
#   '36.1432° N',
#   '35.9271° E',
#   0.0,
#   'Samandag-Hatay',
#   'A',
#   '2023/02/26 12:36:39',
#   'Stations Event'),
#  ('2023/02/26 10:48:23',
#   3.2,
#   'MLv',
#   '36.3556° N',
#   '36.0553° E',
#   0.0,
#   'Belen-Hatay',
#   'A',
#   '2023/02/26 10:52:06',
#   'Stations Event'),
#  ('2023/02/26 09:19:31',
#   3.1,
#   'MLv',
#   '38.0695° N',
#   '37.4396° E',
#   3.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/02/26 09:23:31',
#   'Stations Event'),
#  ('2023/02/26 08:59:24',
#   3.0,
#   'MLv',
#   '36.5094° N',
#   '36.2823° E',
#   0.0,
#   'Kirikhan-Hatay',
#   'A',
#   '2023/02/26 09:02:42',
#   'Stations Event'),
#  ('2023/02/26 07:46:43',
#   3.5,
#   'MLv',
#   '38.1253° N',
#   '38.5172° E',
#   2.0,
#   'Sincik-Adiyaman',
#   'A',
#   '2023/02/26 07:50:02',
#   'Stations Event'),
#  ('2023/02/26 07:16:48',
#   3.6,
#   'MLv',
#   '38.1757° N',
#   '37.8204° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/26 07:20:36',
#   'Stations Event'),
#  ('2023/02/26 06:53:34',
#   2.8,
#   'MLv',
#   '37.1320° N',
#   '36.0846° E',
#   9.0,
#   'Ceyhan-Adana',
#   'A',
#   '2023/02/26 06:57:11',
#   'Stations Event'),
#  ('2023/02/26 06:29:22',
#   3.6,
#   'MLv',
#   '39.5718° N',
#   '27.0964° E',
#   11.0,
#   'Havran-Balikesir',
#   'A',
#   '2023/02/26 07:17:03',
#   'Stations Event'),
#  ('2023/02/26 06:11:49',
#   3.1,
#   'MLv',
#   '38.1537° N',
#   '37.8717° E',
#   11.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/26 06:13:59',
#   'Stations Event'),
#  ('2023/02/26 06:02:46',
#   3.3,
#   'MLv',
#   '38.1821° N',
#   '38.6636° E',
#   0.0,
#   'Puturge-Malatya',
#   'A',
#   '2023/02/26 06:06:05',
#   'Stations Event'),
#  ('2023/02/26 05:43:13',
#   3.1,
#   'MLv',
#   '38.1647° N',
#   '37.9047° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/26 05:46:12',
#   'Stations Event'),
#  ('2023/02/26 05:21:58',
#   3.8,
#   'MLv',
#   '36.7859° N',
#   '36.5588° E',
#   9.0,
#   'Hassa-Hatay',
#   'A',
#   '2023/02/26 06:01:41',
#   'Stations Event'),
#  ('2023/02/26 04:52:43',
#   3.3,
#   'MLv',
#   '37.9962° N',
#   '37.5238° E',
#   0.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/02/26 04:57:21',
#   'Stations Event'),
#  ('2023/02/26 04:47:31',
#   4.0,
#   'MLv',
#   '36.0719° N',
#   '35.7895° E',
#   5.0,
#   'Turkey',
#   'M',
#   '2023/02/27 06:26:34',
#   'Stations Event'),
#  ('2023/02/26 04:37:41',
#   4.0,
#   'MLv',
#   '38.0658° N',
#   '37.1283° E',
#   0.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/02/26 04:57:02',
#   'Stations Event'),
#  ('2023/02/26 04:30:36',
#   2.6,
#   'MLv',
#   '38.9374° N',
#   '41.3947° E',
#   6.0,
#   'Merkez-Mus',
#   'A',
#   '2023/02/26 04:34:29',
#   'Stations Event'),
#  ('2023/02/26 03:58:54',
#   3.5,
#   'MLv',
#   '36.2494° N',
#   '36.0919° E',
#   8.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/02/26 04:31:52',
#   'Stations Event'),
#  ('2023/02/26 03:26:52',
#   3.1,
#   'MLv',
#   '38.0795° N',
#   '36.6403° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/26 03:30:00',
#   'Stations Event'),
#  ('2023/02/26 03:11:30',
#   2.7,
#   'MLv',
#   '37.8790° N',
#   '36.6925° E',
#   6.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/26 03:14:36',
#   'Stations Event'),
#  ('2023/02/26 02:50:54',
#   2.7,
#   'MLv',
#   '38.0457° N',
#   '37.2986° E',
#   2.0,
# ...
#   'MLv',
#   '38.3835° N',
#   '37.9166° E',
#   0.0,
#   'Akcadag-Malatya',
#   'A',
#   '2023/02/15 10:26:57',
#   'Stations Event'),
#  ('2023/02/15 10:14:22',
#   3.9,
#   'MLv',
#   '38.0145° N',
#   '36.4581° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/15 10:17:11',
#   'Stations Event'),
#  ('2023/02/15 10:01:54',
#   3.7,
#   'MLv',
#   '37.1796° N',
#   '36.7035° E',
#   0.0,
#   'Nurdagi-Gaziantep',
#   'A',
#   '2023/02/15 10:05:57',
#   'Stations Event'),
#  ('2023/02/15 09:02:07',
#   2.4,
#   'MLv',
#   '39.7723° N',
#   '26.3031° E',
#   5.0,
#   'Ezine-Canakkale',
#   'A',
#   '2023/02/15 09:06:08',
#   'Stations Event'),
#  ('2023/02/15 08:51:43',
#   3.4,
#   'MLv',
#   '38.0988° N',
#   '37.4542° E',
#   12.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/02/15 08:54:05',
#   'Stations Event'),
#  ('2023/02/15 08:35:19',
#   3.5,
#   'MLv',
#   '38.0887° N',
#   '36.6129° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/15 08:38:04',
#   'Stations Event'),
#  ('2023/02/15 08:20:01',
#   3.6,
#   'MLv',
#   '37.3480° N',
#   '37.1942° E',
#   0.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/15 08:23:57',
#   'Stations Event'),
#  ('2023/02/15 07:36:31',
#   4.4,
#   'mb',
#   '37.9534° N',
#   '36.5179° E',
#   10.0,
#   'Goksun-Kahramanmaras',
#   'M',
#   '2023/02/15 08:46:25',
#   'Stations Event'),
#  ('2023/02/15 07:35:19',
#   5.5,
#   'mb',
#   '51.2093° N',
#   '179.3135° W',
#   10.0,
#   'Andreanof Islands, Aleutian Islands',
#   'A',
#   '2023/02/15 08:21:13',
#   'Stations Event'),
#  ('2023/02/15 06:58:47',
#   3.0,
#   'MLv',
#   '38.0743° N',
#   '37.8604° E',
#   5.0,
#   'Dogansehir-Malatya',
#   'M',
#   '2023/02/15 07:35:38',
#   'Stations Event'),
#  ('2023/02/15 06:38:09',
#   5.8,
#   'mb',
#   '40.5188° S',
#   '174.4861° E',
#   67.0,
#   'Cook Strait, New Zealand',
#   'A',
#   '2023/02/15 10:52:07',
#   'Stations Event'),
#  ('2023/02/15 06:25:30',
#   4.3,
#   'MLv',
#   '38.0960° N',
#   '36.6861° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/15 06:41:43',
#   'Stations Event'),
#  ('2023/02/15 06:17:11',
#   3.3,
#   'MLv',
#   '37.7970° N',
#   '36.6311° E',
#   10.0,
#   'Merkez-Kahramanmaras',
#   'M',
#   '2023/02/15 07:33:14',
#   'Stations Event'),
#  ('2023/02/15 05:45:42',
#   3.1,
#   'MLv',
#   '37.5421° N',
#   '37.4432° E',
#   30.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/15 05:49:42',
#   'Stations Event'),
#  ('2023/02/15 05:10:52',
#   2.8,
#   'MLv',
#   '38.1171° N',
#   '25.9589° E',
#   6.0,
#   'Aegean Sea',
#   'A',
#   '2023/02/15 05:13:22',
#   'Stations Event'),
#  ('2023/02/15 04:42:39',
#   3.5,
#   'MLv',
#   '37.4908° N',
#   '37.1722° E',
#   0.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/15 04:46:31',
#   'Stations Event'),
#  ('2023/02/15 04:27:18',
#   2.7,
#   'MLv',
#   '38.3305° N',
#   '40.2715° E',
#   11.0,
#   'Dicle-Diyarbakir',
#   'M',
#   '2023/02/15 06:38:28',
#   'Stations Event'),
#  ('2023/02/15 03:51:23',
#   3.6,
#   'MLv',
#   '36.3501° N',
#   '35.9791° E',
#   5.0,
#   'iskenderun-Hatay',
#   'A',
#   '2023/02/15 03:55:43',
#   'Stations Event'),
#  ('2023/02/15 03:03:30',
#   2.4,
#   'MLv',
#   '39.7742° N',
#   '26.3036° E',
#   8.0,
#   'Ezine-Canakkale',
#   'A',
#   '2023/02/15 03:06:59',
#   'Stations Event'),
#  ('2023/02/15 03:03:29',
#   3.3,
#   'MLv',
#   '37.5275° N',
#   '37.1210° E',
#   0.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/15 03:06:57',
#   'Stations Event'),
#  ('2023/02/15 02:15:10',
#   3.0,
#   'MLv',
#   '38.6737° N',
#   '40.0104° E',
#   0.0,
#   'Palu-Elazig',
#   'A',
#   '2023/02/15 02:19:32',
#   'Stations Event'),
#  ('2023/02/15 01:47:17',
#   2.4,
#   'MLv',
#   '38.7081° N',
#   '39.9276° E',
#   5.0,
#   'Palu-Elazig',
#   'M',
#   '2023/02/15 06:40:33',
#   'Stations Event'),
#  ('2023/02/15 01:43:23',
#   4.0,
#   'MLv',
#   '38.7506° N',
#   '40.0031° E',
#   7.0,
#   'Kovancilar-Elazig',
#   'A',
#   '2023/02/15 01:46:46',
#   'Stations Event'),
#  ('2023/02/15 01:15:39',
#   3.3,
#   'MLv',
#   '36.3743° N',
#   '36.2625° E',
#   2.0,
#   'Merkez-Hatay',
#   'M',
#   '2023/02/15 06:45:43',
#   'Stations Event'),
#  ('2023/02/15 00:47:37',
#   3.4,
#   'MLv',
#   '38.0109° N',
#   '37.4615° E',
#   0.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/02/15 00:50:12',
#   'Stations Event'),
#  ('2023/02/15 00:21:23',
#   3.1,
#   'MLv',
#   '36.4325° N',
#   '36.2384° E',
#   0.0,
#   'Belen-Hatay',
#   'A',
#   '2023/02/15 00:25:02',
#   'Stations Event'),
#  ('2023/02/15 00:10:58',
#   3.6,
#   'MLv',
#   '37.9587° N',
#   '36.4133° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/15 00:14:59',
#   'Stations Event'),
#  ('2023/02/15 00:06:03',
#   4.4,
#   'MLv',
#   '36.7914° N',
#   '36.5314° E',
#   8.0,
#   'Hassa-Hatay',
#   'A',
#   '2023/02/15 00:23:35',
#   'Stations Event'),
#  ('2023/02/14 23:54:48',
#   3.0,
#   'MLv',
#   '37.3073° N',
#   '37.1163° E',
#   5.0,
#   'Pazarcik-Kahramanmaras',
#   'M',
#   '2023/02/15 06:50:24',
#   'Stations Event'),
#  ('2023/02/14 23:24:15',
#   3.4,
#   'MLv',
#   '38.0621° N',
#   '38.1757° E',
#   0.0,
#   'Celikhan-Adiyaman',
#   'A',
#   '2023/02/14 23:27:53',
#   'Stations Event'),
#  ('2023/02/14 23:14:02',
#   4.7,
#   'MLv',
#   '38.5757° N',
#   '37.5577° E',
#   0.0,
#   'Darende-Malatya',
#   'A',
#   '2023/02/14 23:44:32',
#   'Stations Event'),
#  ('2023/02/14 23:01:32',
#   3.0,
#   'MLv',
#   '36.6803° N',
#   '36.4470° E',
#   3.0,
#   'Hassa-Hatay',
#   'M',
#   '2023/02/15 07:01:52',
#   'Stations Event'),
#  ('2023/02/14 22:54:31',
#   2.4,
#   'MLv',
#   '38.0018° N',
#   '36.4846° E',
#   3.0,
#   'Goksun-Kahramanmaras',
#   'M',
#   '2023/02/15 07:04:34',
#   'Stations Event'),
#  ('2023/02/14 22:09:27',
#   3.1,
#   'MLv',
#   '38.0746° N',
#   '37.1671° E',
#   2.0,
#   'Ekinozu-Kahramanmaras',
#   'M',
#   '2023/02/15 07:06:46',
#   'Stations Event'),
#  ('2023/02/14 21:53:16',
#   3.9,
#   'MLv',
#   '36.6925° N',
#   '36.4252° E',
#   3.0,
#   'Hassa-Hatay',
#   'A',
#   '2023/02/14 21:57:30',
#   'Stations Event'),
#  ('2023/02/14 21:44:41',
#   3.1,
#   'MLv',
#   '38.0701° N',
#   '36.5925° E',
#   5.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/14 21:47:47',
#   'Stations Event'),
#  ('2023/02/14 21:36:15',
#   3.6,
#   'MLv',
#   '37.8259° N',
#   '36.6687° E',
#   1.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/14 21:39:29',
#   'Stations Event'),
#  ('2023/02/14 21:30:42',
#   3.3,
#   'MLv',
#   '38.1747° N',
#   '38.5464° E',
#   0.0,
#   'Merkez-Malatya',
#   'A',
#   '2023/02/14 21:34:33',
#   'Stations Event'),
#  ('2023/02/14 21:25:31',
#   3.2,
#   'MLv',
#   '38.2526° N',
#   '37.1942° E',
#   0.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/02/14 21:29:19',
#   'Stations Event'),
#  ('2023/02/14 20:51:17',
#   2.9,
#   'MLv',
#   '38.0188° N',
#   '36.4820° E',
#   5.0,
#   'Goksun-Kahramanmaras',
#   'M',
#   '2023/02/15 07:10:15',
#   'Stations Event'),
#  ('2023/02/14 20:32:39',
#   3.6,
#   'MLv',
#   '44.9084° N',
#   '23.0530° E',
#   15.0,
#   'Romania',
#   'A',
#   '2023/02/14 20:37:25',
#   'Stations Event'),
#  ('2023/02/14 20:32:28',
#   3.7,
#   'MLv',
#   '45.3489° N',
#   '22.6911° E',
#   5.0,
#   'Romania',
#   'A',
#   '2023/02/14 20:37:27',
#   'Stations Event'),
#  ('2023/02/14 20:08:04',
#   3.7,
#   'MLv',
#   '37.6996° N',
#   '37.7252° E',
#   15.0,
#   'Besni-Adiyaman',
#   'A',
#   '2023/02/14 20:11:37',
#   'Stations Event'),
#  ('2023/02/14 19:45:57',
#   2.5,
#   'MLv',
#   '37.1265° N',
#   '28.7385° E',
#   10.0,
#   'Koycegiz-Mugla',
#   'A',
#   '2023/02/14 19:48:18',
#   'Stations Event'),
#  ('2023/02/14 19:32:38',
#   3.1,
#   'MLv',
#   '37.7802° N',
#   '37.7252° E',
#   1.0,
#   'Golbasi-Adiyaman',
#   'A',
#   '2023/02/14 19:36:38',
#   'Stations Event'),
#  ('2023/02/14 19:15:56',
#   3.2,
#   'MLv',
#   '37.1741° N',
#   '36.2878° E',
#   9.0,
#   'Merkez-Osmaniye',
#   'A',
#   '2023/02/14 19:19:51',
#   'Stations Event'),
#  ('2023/02/14 18:16:10',
#   2.3,
#   'MLv',
#   '45.1945° N',
#   '23.1700° E',
#   7.0,
#   'Romania',
#   'M',
#   '2023/02/15 07:13:48',
#   'Stations Event'),
#  ('2023/02/14 17:59:15',
#   3.5,
#   'MLv',
#   '45.1044° N',
#   '23.1354° E',
#   11.0,
#   'Romania',
#   'A',
#   '2023/02/14 18:03:15',
#   'Stations Event'),
#  ('2023/02/14 17:52:55',
#   3.9,
#   'MLv',
#   '36.0242° N',
#   '36.1194° E',
#   12.0,
#   'Yayladagi-Hatay',
#   'A',
#   '2023/02/14 17:56:50',
#   'Stations Event'),
#  ('2023/02/14 17:36:57',
#   2.0,
#   'MLv',
#   '39.3695° N',
#   '26.2299° E',
#   13.0,
#   'Midilli Adasi-Ege Denizi',
#   'A',
#   '2023/02/14 17:39:04',
#   'Stations Event'),
#  ('2023/02/14 16:51:09',
#   3.7,
#   'MLv',
#   '38.3002° N',
#   '37.8204° E',
#   0.0,
#   'Akcadag-Malatya',
#   'A',
#   '2023/02/14 16:54:22',
#   'Stations Event'),
#  ('2023/02/14 16:02:48',
#   2.2,
#   'MLv',
#   '39.3768° N',
#   '26.2665° E',
#   11.0,
#   'Turkey',
#   'A',
#   '2023/02/14 16:06:56',
#   'Stations Event'),
#  ('2023/02/14 15:50:37',
#   4.4,
#   'MLv',
#   '38.0319° N',
#   '37.2629° E',
#   0.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/02/14 16:06:38',
#   'Stations Event'),
#  ('2023/02/14 15:47:33',
#   4.0,
#   'MLv',
#   '45.1282° N',
#   '23.1628° E',
#   13.0,
#   'Romania',
#   'A',
#   '2023/02/14 15:52:16',
#   'Stations Event'),
#  ('2023/02/14 15:24:27',
#   4.3,
#   'MLv',
#   '45.0952° N',
#   '23.1519° E',
#   5.0,
#   'Romania',
#   'A',
#   '2023/02/14 16:13:56',
#   'Stations Event'),
#  ('2023/02/14 13:44:16',
#   3.4,
#   'MLv',
#   '35.7394° N',
#   '34.2878° E',
#   5.0,
#   'Cyprus Region',
#   'M',
#   '2023/02/15 08:06:50',
#   'Stations Event'),
#  ('2023/02/14 13:16:52',
#   5.8,
#   'Mwp',
#   '45.1473° N',
#   '23.2556° E',
#   17.0,
#   'Romania',
#   'M',
#   '2023/02/14 14:05:58',
#   'Stations Event'),
#  ('2023/02/14 13:13:06',
#   3.9,
#   'MLv',
#   '37.8891° N',
#   '37.9752° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/14 13:17:12',
#   'Stations Event'),
#  ('2023/02/14 13:04:53',
#   2.5,
#   'MLv',
#   '37.2187° N',
#   '36.7740° E',
#   10.0,
#   'Nurdagi-Gaziantep',
#   'M',
#   '2023/02/15 07:18:51',
#   'Stations Event'),
#  ('2023/02/14 12:43:13',
#   3.9,
#   'MLv',
#   '38.0988° N',
#   '38.2086° E',
#   0.0,
#   'Celikhan-Adiyaman',
#   'A',
#   '2023/02/14 12:46:20',
#   'Stations Event'),
#  ('2023/02/14 11:54:11',
#   4.2,
#   'MLv',
#   '36.0518° N',
#   '36.0759° E',
#   7.0,
#   'Merkez-Hatay',
#   'A',
#   '2023/02/14 12:48:58',
#   'Stations Event'),
#  ('2023/02/14 11:36:37',
#   3.5,
#   'MLv',
#   '38.1381° N',
#   '36.5872° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/14 11:40:41',
#   'Stations Event'),
#  ('2023/02/14 11:07:46',
#   3.8,
#   'MLv',
#   '38.0063° N',
#   '36.3675° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/14 11:11:23',
#   'Stations Event'),
#  ('2023/02/14 11:04:14',
#   3.7,
#   'MLv',
#   '38.0328° N',
#   '36.6339° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/14 11:07:06',
#   'Stations Event'),
#  ('2023/02/14 10:11:58',
#   3.0,
#   'MLv',
#   '38.0685° N',
#   '36.5836° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/14 10:14:44',
#   'Stations Event'),
#  ('2023/02/14 09:56:32',
#   2.0,
#   'MLv',
#   '36.1322° N',
#   '33.5431° E',
#   0.0,
#   'Gulnar-Mersin',
#   'A',
#   '2023/02/14 09:59:02',
#   'Stations Event'),
#  ('2023/02/14 09:10:42',
#   3.2,
#   'MLv',
#   '37.5485° N',
#   '37.3398° E',
#   0.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/14 09:14:28',
#   'Stations Event'),
#  ('2023/02/14 08:44:19',
#   3.2,
#   'MLv',
#   '38.1381° N',
#   '36.9168° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/14 08:47:23',
#   'Stations Event'),
#  ('2023/02/14 08:16:58',
#   3.3,
#   'MLv',
#   '38.2782° N',
#   '38.8202° E',
#   0.0,
#   'Puturge-Malatya',
#   'A',
#   '2023/02/14 08:20:09',
#   'Stations Event'),
#  ('2023/02/14 06:41:31',
#   3.4,
#   'MLv',
#   '37.9568° N',
#   '36.2448° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/14 06:44:57',
#   'Stations Event'),
#  ('2023/02/14 05:17:42',
#   2.4,
#   'MLv',
#   '41.0495° N',
#   '27.6480° E',
#   14.0,
#   'Merkez-Tekirdag',
#   'A',
#   '2023/02/14 05:21:05',
#   'Stations Event'),
#  ('2023/02/14 04:58:41',
#   3.8,
#   'MLv',
#   '38.0429° N',
#   '37.4240° E',
#   0.0,
#   'Nurhak-Kahramanmaras',
#   'A',
#   '2023/02/14 05:02:23',
#   'Stations Event'),
#  ('2023/02/14 04:17:24',
#   3.1,
#   'MLv',
#   '39.9326° N',
#   '39.8172° E',
#   0.0,
#   'Demirozu-Bayburt',
#   'A',
#   '2023/02/14 04:19:46',
#   'Stations Event'),
#  ('2023/02/14 03:49:26',
#   3.0,
#   'MLv',
#   '39.2340° N',
#   '43.5773° E',
#   0.0,
#   'Ercis-Van',
#   'A',
#   '2023/02/14 03:53:11',
#   'Stations Event'),
#  ('2023/02/14 03:17:37',
#   3.5,
#   'MLv',
#   '38.2993° N',
#   '38.3157° E',
#   0.0,
#   'Merkez-Malatya',
#   'A',
#   '2023/02/14 03:22:30',
#   'Stations Event'),
#  ('2023/02/14 03:05:16',
#   3.7,
#   'MLv',
#   '38.0579° N',
#   '36.6077° E',
#   10.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/14 03:09:27',
#   'Stations Event'),
#  ('2023/02/14 02:49:04',
#   4.3,
#   'MLv',
#   '37.5696° N',
#   '40.6091° E',
#   77.0,
#   'Mazidagi-Mardin',
#   'A',
#   '2023/02/14 02:53:24',
#   'Stations Event'),
#  ('2023/02/14 02:18:17',
#   2.6,
#   'MLv',
#   '38.2260° N',
#   '32.0279° E',
#   0.0,
#   'Ilgin-Konya',
#   'A',
#   '2023/02/14 02:21:22',
#   'Stations Event'),
#  ('2023/02/14 01:56:34',
#   3.7,
#   'MLv',
#   '36.6705° N',
#   '36.4471° E',
#   8.0,
#   'Hassa-Hatay',
#   'A',
#   '2023/02/14 02:00:36',
#   'Stations Event'),
#  ('2023/02/14 01:51:32',
#   3.3,
#   'MLv',
#   '37.5229° N',
#   '37.2757° E',
#   0.0,
#   'Pazarcik-Kahramanmaras',
#   'A',
#   '2023/02/14 01:55:34',
#   'Stations Event'),
#  ('2023/02/14 01:06:46',
#   3.2,
#   'MLv',
#   '38.1088° N',
#   '37.7463° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/14 01:10:27',
#   'Stations Event'),
#  ('2023/02/14 00:54:59',
#   3.6,
#   'MLv',
#   '38.0576° N',
#   '37.8085° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/14 00:59:01',
#   'Stations Event'),
#  ('2023/02/14 00:50:57',
#   4.0,
#   'MLv',
#   '37.9971° N',
#   '36.6495° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/14 00:55:06',
#   'Stations Event'),
#  ('2023/02/14 00:20:04',
#   3.3,
#   'MLv',
#   '39.6460° N',
#   '23.3862° E',
#   13.0,
#   'Aegean Sea',
#   'A',
#   '2023/02/14 00:23:49',
#   'Stations Event'),
#  ('2023/02/13 23:57:41',
#   1.8,
#   'MLv',
#   '36.1230° N',
#   '33.6035° E',
#   5.0,
#   'Turkey',
#   'A',
#   '2023/02/13 23:59:03',
#   'Stations Event'),
#  ('2023/02/13 23:56:21',
#   2.6,
#   'MLv',
#   '39.1498° N',
#   '42.0575° E',
#   0.0,
#   'Bulanik-Mus',
#   'A',
#   '2023/02/13 23:58:31',
#   'Stations Event'),
#  ('2023/02/13 23:49:34',
#   3.9,
#   'MLv',
#   '38.0191° N',
#   '36.5341° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/13 23:53:18',
#   'Stations Event'),
#  ('2023/02/13 23:03:38',
#   3.2,
#   'MLv',
#   '37.1054° N',
#   '28.9224° E',
#   9.0,
#   'Koycegiz-Mugla',
#   'A',
#   '2023/02/13 23:40:02',
#   'Stations Event'),
#  ('2023/02/13 23:02:16',
#   3.1,
#   'MLv',
#   '37.9623° N',
#   '34.0585° E',
#   0.0,
#   'Bor-Nigde',
#   'A',
#   '2023/02/13 23:05:49',
#   'Stations Event'),
#  ('2023/02/13 22:55:20',
#   3.1,
#   'MLv',
#   '37.6657° N',
#   '35.3549° E',
#   0.0,
#   'Aladag-Adana',
#   'A',
#   '2023/02/13 22:58:27',
#   'Stations Event'),
#  ('2023/02/13 21:32:10',
#   3.1,
#   'MLv',
#   '38.0887° N',
#   '37.0157° E',
#   0.0,
#   'Ekinozu-Kahramanmaras',
#   'A',
#   '2023/02/13 21:35:42',
#   'Stations Event'),
#  ('2023/02/13 21:11:23',
#   2.9,
#   'MLv',
#   '38.0768° N',
#   '37.6447° E',
#   4.0,
#   'Elbistan-Kahramanmaras',
#   'A',
#   '2023/02/13 21:13:49',
#   'Stations Event'),
#  ('2023/02/13 20:39:40',
#   3.7,
#   'MLv',
#   '38.3826° N',
#   '23.4631° E',
#   11.0,
#   'Greece',
#   'A',
#   '2023/02/13 21:01:28',
#   'Stations Event'),
#  ('2023/02/13 20:21:42',
#   3.0,
#   'MLv',
#   '38.1161° N',
#   '36.6422° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/13 20:24:49',
#   'Stations Event'),
#  ('2023/02/13 20:07:29',
#   2.9,
#   'MLv',
#   '38.0612° N',
#   '36.4334° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/13 20:10:33',
#   'Stations Event'),
#  ('2023/02/13 19:20:27',
#   4.9,
#   'MLv',
#   '38.0429° N',
#   '36.4224° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/13 19:24:18',
#   'Stations Event'),
#  ('2023/02/13 19:08:24',
#   3.0,
#   'MLv',
#   '37.8799° N',
#   '36.3199° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/13 19:11:30',
#   'Stations Event'),
#  ('2023/02/13 18:49:01',
#   3.2,
#   'MLv',
#   '37.8671° N',
#   '36.6916° E',
#   0.0,
#   'Merkez-Kahramanmaras',
#   'A',
#   '2023/02/13 18:51:52',
#   'Stations Event'),
#  ('2023/02/13 18:28:39',
#   3.6,
#   'MLv',
#   '38.0109° N',
#   '36.5497° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/13 18:32:26',
#   'Stations Event'),
#  ('2023/02/13 18:07:44',
#   3.0,
#   'MLv',
#   '38.1125° N',
#   '37.8598° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/13 18:11:06',
#   'Stations Event'),
#  ('2023/02/13 17:53:42',
#   2.8,
#   'MLv',
#   '38.2965° N',
#   '38.1683° E',
#   0.0,
#   'Yesilyurt-Malatya',
#   'A',
#   '2023/02/13 17:56:05',
#   'Stations Event'),
#  ('2023/02/13 17:19:00',
#   3.0,
#   'MLv',
#   '38.0658° N',
#   '37.9449° E',
#   0.0,
#   'Dogansehir-Malatya',
#   'A',
#   '2023/02/13 17:22:13',
#   'Stations Event'),
#  ('2023/02/13 17:13:31',
#   3.6,
#   'MLv',
#   '38.0978° N',
#   '36.6385° E',
#   0.0,
#   'Goksun-Kahramanmaras',
#   'A',
#   '2023/02/13 17:17:23',
#   'Stations Event'),
#  ...]

# %% [markdown]
# ## Retrieve the whole dataset and Display

# %%
# Setup pandas display template

pd.set_option('display.width', 700)
pd.set_option('display.max_columns', 9)

# %%
# Read the Dataset from the database
import sqlite3
# Create a connection to the databse
conn = sqlite3.connect('data/earthquake-in-turkey.db')

# Read out the whole dataset as dataframe
df = pd.read_sql_query("SELECT * FROM quaketk", conn)
df
# Out:
#             origintimeutc  magnitude magtype    latitude  ...                       region  measmethod              updtime       attribute
# 0     2023/03/08 09:26:29        3.6     MLv  37.9047° N  ...         Merkez-Kahramanmaras           A  2023/03/08 09:30:28  Stations Event
# 1     2023/03/08 08:41:55        3.3     MLv  36.3025° N  ...                 Merkez-Hatay           A  2023/03/08 08:45:45  Stations Event
# 2     2023/03/08 07:32:07        2.9     MLv  38.6948° N  ...              Hacilar-Kayseri           A  2023/03/08 07:35:01  Stations Event
# 3     2023/03/08 03:23:37        3.4     MLv  38.0795° N  ...         Nurhak-Kahramanmaras           A  2023/03/08 03:26:58  Stations Event
# 4     2023/03/08 02:52:37        2.0     MLv  36.6640° N  ...                   Mut-Mersin           M  2023/03/08 06:02:41  Stations Event
# ...                   ...        ...     ...         ...  ...                          ...         ...                  ...             ...
# 2014  2023/01/16 22:19:00        2.4     MLv  39.5278° N  ...                   Aegean Sea           M  2023/01/17 10:47:00  Stations Event
# 2015  2023/01/16 22:07:00        3.1     MLv  39.3431° N  ...     Midilli Adasi-Ege Denizi           M  2023/01/17 10:44:00  Stations Event
# 2016  2023/01/16 22:05:00        3.4     MLv  36.9406° N  ...  Dodecanese Islands,  Greece           M  2023/01/17 10:41:00  Stations Event
# 2017  2023/01/16 21:58:00        2.9     MLv  39.4010° N  ...                       Turkey           M  2023/01/17 10:24:00  Stations Event
# 2018  2023/01/16 21:35:00        2.5     MLv  39.5220° N  ...  Ayvacik Aciklari-EGE DENIZI           M  2023/01/17 09:38:00  Stations Event
#
# [2019 rows x 10 columns]

# %%
print('Time Range of the Dataset is between:', df['origintimeutc'].min(), 'and', df['origintimeutc'].max())
# Out:
# Time Range of the Dataset is between: 2023/01/16 21:35:00 and 2023/03/08 09:26:29

# %%
# Re-treatment of the dataset
df['origintimeutc'] = df['origintimeutc'].apply(lambda x: dt.datetime.strptime(x,'%Y/%m/%d %H:%M:%S') if type(x)==str else pd.NaT)
df['magnitude'] = df['magnitude'].astype('float')
df['magtype'] = df['magtype'].astype('string')

df['latitude'] = df['latitude'].astype(str).map(lambda x: x.rstrip('° N').rstrip('° S'))
df['longitude'] = df['longitude'].astype(str).map(lambda x: x.rstrip('° E').rstrip('° W'))
df['depthkm'] = df['depthkm'].replace('-', 0).astype("float")

df['region'] = df['region'].astype('string')
df['measmethod'] = df['measmethod'].astype('string')
df['updtime'] = df['updtime'].apply(lambda x: dt.datetime.strptime(x,'%Y/%m/%d %H:%M:%S') if type(x)==str else pd.NaT)
df['attribute'] = df['attribute'].astype('string')

# Adjust datetime from UTC (GMT) to Turkey timezone (GMT+3)
df['eventtime'] = df['origintimeutc'] + pd.DateOffset(hours=3)
df['updtime'] = df['updtime'] + pd.DateOffset(hours=3)

# Create new columns for date and time
df['date'] = pd.to_datetime(df['eventtime']).dt.date
df['time'] = pd.to_datetime(df['eventtime']).dt.time

# take a look
df.head()
# Out:
#         origintimeutc  magnitude magtype latitude  ...       attribute           eventtime        date      time
# 0 2023-03-08 09:26:29        3.6     MLv  37.9047  ...  Stations Event 2023-03-08 12:26:29  2023-03-08  12:26:29
# 1 2023-03-08 08:41:55        3.3     MLv  36.3025  ...  Stations Event 2023-03-08 11:41:55  2023-03-08  11:41:55
# 2 2023-03-08 07:32:07        2.9     MLv  38.6948  ...  Stations Event 2023-03-08 10:32:07  2023-03-08  10:32:07
# 3 2023-03-08 03:23:37        3.4     MLv  38.0795  ...  Stations Event 2023-03-08 06:23:37  2023-03-08  06:23:37
# 4 2023-03-08 02:52:37        2.0     MLv  36.6640  ...  Stations Event 2023-03-08 05:52:37  2023-03-08  05:52:37
#
# [5 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['origintimeutc', 'magnitude', 'magtype', 'latitude', 'longitude', 'depthkm', 'region', 'measmethod', 'updtime', 'attribute', 'eventtime', 'date', 'time'], dtype='object')

# %%
# Subset the df and rename the columns
df2 = df[['date', 'time', 'latitude', 'longitude', 'depthkm', 'magnitude', 'magtype', 'region', 'measmethod', 'eventtime', 'updtime', 'attribute']]
df2.head()
# print the earthquake with magnitude >=4
print(df2[df2['magnitude'].astype('float') >= 5])
# Out:
#             date      time latitude longitude  ...  measmethod           eventtime             updtime       attribute
# 122   2023-03-02  09:14:47  43.5305  147.2541  ...           A 2023-03-02 09:14:47 2023-03-02 09:43:49  Stations Event
# 126   2023-03-02  07:40:45  16.3600   94.1429  ...           A 2023-03-02 07:40:45 2023-03-02 08:21:05  Stations Event
# 136   2023-03-02  02:05:23   1.6149  100.7994  ...           A 2023-03-02 02:05:23 2023-03-02 02:45:57  Stations Event
# 142   2023-03-01  22:28:08  14.0322  146.6745  ...           A 2023-03-01 22:28:08 2023-03-01 23:21:55  Stations Event
# 166   2023-03-01  08:36:15   4.8343  149.4758  ...           A 2023-03-01 08:36:15 2023-03-01 09:24:27  Stations Event
# ...          ...       ...      ...       ...  ...         ...                 ...                 ...             ...
# 1950  2023-01-21  01:09:00  26.7416   63.1257  ...           A 2023-01-21 01:09:00 2023-01-21 02:11:00  Stations Event
# 1954  2023-01-20  14:23:00  16.0723   62.1434  ...           A 2023-01-20 14:23:00 2023-01-20 14:36:00  Stations Event
# 1991  2023-01-18  13:08:00  38.0603   45.2820  ...           A 2023-01-18 13:08:00 2023-01-18 13:32:00  Stations Event
# 1994  2023-01-18  09:06:00   2.7208  127.0376  ...           A 2023-01-18 09:06:00 2023-01-18 11:08:00  Stations Event
# 1998  2023-01-18  03:34:00   0.0339  123.1446  ...           A 2023-01-18 03:34:00 2023-01-18 09:24:00  Stations Event
#
# [119 rows x 12 columns]

# %%
# Define our functions
def addCircles(df, map):
    for x, y, z, loc, date, time in zip(df['latitude'], df['longitude'], df['magnitude'], df['region'], df['date'], df['time']):
        popUp = f"<p style='text-align: center;'><span style='font-family: Verdana, Geneva, sans-serif; font-size: 12px; color: rgb(40, 50, 78);'><strong>Magnitude: {z} ML&nbsp;</strong></span></p>" \
                f"<p style='text-align: center;'><span style='font-family: Verdana, Geneva, sans-serif; font-size: 12px; color: rgb(40, 50, 78);'><strong>Location: {loc}</strong></span></p>" \
                f"<p style='text-align: center;'><span style='font-family: Verdana, Geneva, sans-serif; font-size: 12px; color: rgb(40, 50, 78);'><strong>Date: {date}</strong></span></p>" \
                f"<p style='text-align: center;'><span style='font-family: Verdana, Geneva, sans-serif; font-size: 12px; color: rgb(40, 50, 78);'><strong>Time: {time}</strong></span></p>"
        iframe = folium.IFrame(popUp, width=250, height=150)
        popup = folium.Popup(iframe, max_width=450)
        folium.CircleMarker(location=(x, y), radius=float(z) * 4, weight=2, opacity=1, popup=popup,
                            color="red", fill_color="red", fill_opacity=0.1).add_to(map)

# %%
# Setup initial map

magThreshold = 5

earthquakeMap = folium.Map(location=[39.16, 35.66], zoom_start=6, tiles="Stamen Terrain")

# Load up the polygon (in GeoJson format) around turkey
# Original URL was - https://raw.githubusercontent.com/fraxen/tectonicplates/master/GeoJSON/PB2002_boundaries.json
folium.GeoJson('data/PB2002_boundaries.json', name="geojson").add_to(earthquakeMap)

# Add tiles
folium.TileLayer('Stamen Terrain').add_to(earthquakeMap)
folium.TileLayer('Stamen Toner').add_to(earthquakeMap)
folium.TileLayer('Stamen Water Color').add_to(earthquakeMap)
folium.TileLayer('cartodbpositron').add_to(earthquakeMap)
folium.TileLayer('cartodbdark_matter').add_to(earthquakeMap)
folium.LayerControl().add_to(earthquakeMap)

# add Circles (sizing per magnitude)
earthquakeDF = df2[df2['magnitude'].astype('float') >= magThreshold]
addCircles(earthquakeDF, earthquakeMap)

# Take a look at the map
# earthquakeMap

# %%
# Display the map inline at Jupyter with settings of Width and Height

width, height = 960, 640
fig = folium.Figure(width=width, height=height)
fig.add_child(earthquakeMap)

fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2c7178cc2de9ea25ebe7bfceb27490f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2c7178cc2de9ea25ebe7bfceb27490f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2c7178cc2de9ea25ebe7bfceb27490f = L.map(
#                 &quot;map_e2c7178cc2de9ea25ebe7bfceb27490f&quot;,
#                 {
#                     center: [39.16, 35.66],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d00e3d0a39c5beef670c47e953c32d51 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e2c7178cc2de9ea25ebe7bfceb27490f);
#
#
#
#         function geo_json_a4b8042770cf038b79540c6e15d99fe4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a4b8042770cf038b79540c6e15d99fe4 = L.geoJson(null, {
#                 onEachFeature: geo_json_a4b8042770cf038b79540c6e15d99fe4_onEachFeature,
#
#         });
#
#         function geo_json_a4b8042770cf038b79540c6e15d99fe4_add (data) {
#             geo_json_a4b8042770cf038b79540c6e15d99fe4
#                 .addData(data)
#                 .addTo(map_e2c7178cc2de9ea25ebe7bfceb27490f);
#         }
#             geo_json_a4b8042770cf038b79540c6e15d99fe4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.4379, -54.8518], [-0.038826, -54.6772], [0.443182, -54.4512], [0.964534, -54.8322], [1.69481, -54.399], [2.35975, -54.0374], [3.02542, -53.6507], [3.36894, -53.8341], [3.95638, -54.1267], [4.41458, -54.4303], [4.82661, -54.1616], [5.08372, -54.3093], [5.49469, -54.5429], [6.18373, -54.1145], [6.6254, -53.8142], [7.23729, -54.1012], [7.77235, -54.396]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;plate boundary&quot;, &quot;Name&quot;: &quot;AF-AN&quot;, &quot;PlateA&quot;: &quot;AF&quot;, &quot;PlateB&quot;: &quot;AN&quot;, &quot;Source&quot;: &quot;Mueller et al. [1987]&quot;, &quot;Type&quot;: &quot;&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[7.77235, -54.396], [8.28834, -54.0326], [8.79876, -53.668], [9.42869, -53.2326], [9.99306, -52.7923], [10.5424, -53.0655], [10.9748, -53.332], [11.7084, -52.7829], [12.2989, -52.375], [12.8951, -51.9629], [13.2042, -52.141], [13.7876, -52.4769], [14.4633, -51.9971], [15.1124, -52.3075], [15.428, -52.0836], [15.8223, -51.787], [16.9072, -52.1693], [17.8063, -52.4669], [18.5374, -52.7343], [18.7125, -52.5529], [19.9938, -52.8167], [21.2504, -52.9088], [22.5042, -53.0512], [23.0753, -53.0977], [23.0214, -53.2004], [23.8862, -53.3086], [24.6851, -53.4215], [24.8726, -53.3453]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;plate boundary&quot;, &quot;Name&quot;: &quot;AF-AN&quot;, &quot;PlateA&quot;: &quot;AF&quot;, &quot;PlateB&quot;: &quot;AN&quot;, &quot;Source&quot;: &quot;by Peter Bird, October 2001&quot;, &quot;Type&quot;: &quot;&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[32.1258, -46.9998], [31.8654, -47.2011], [31.5885, -47.6822], [31.3065, -48.1627], [31.0081, -48.5871], [30.7046, -49.0106], [30.3617, -49.2155], [30.006, -49.6108], [29.7115, -49.9335], [29.3431, -50.507], [28.9688, -51.1373], [28.6054, -51.7716], [28.4027, -52.2771], [28.3122, -52.54], [28.1108, -52.9037], [27.4795, -52.7708], [27.3704, -52.673], [27.3221, -52.5472], [26.7131, -52.378], [26.5129, -52.6201], [26.3382, -53.065], [26.1809, -53.4288], [25.9869, -53.5818], [25.8614, -53.4799], [25.6475, -53.41], [25.1797, -53.4441], [24.8726, -53.3453]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;plate boundary&quot;, &quot;Name&quot;: &quot;AN-AF&quot;, &quot;PlateA&quot;: &quot;AN&quot;, &quot;PlateB&quot;: &quot;AF&quot;, &quot;Source&quot;: &quot;Lemaux et al. [2002]&quot;, &quot;Type&quot;: &quot;&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[32.1258, -46.9998], [33.1739, -47.2644], [33.3585, -46.8055], [33.54, -46.3464], [33.8184, -45.9791], [33.9824, -46.0812], [34.0869, -46.0899], [34.2672, -46.2123], [34.5037, -46.2216], [34.704, -45.9714], [34.8682, -45.4657], [35.0145, -45.1058], [35.1819, -44.8555], [35.6603, -44.866], [35.9729, -44.9607], [36.3029, -44.9665], [36.6774, -44.9197], [37.0855, -44.8043], [37.5083, -44.8753], [38.0827, -44.6188]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;plate boundary&quot;, &quot;Name&quot;: &quot;SO-AN&quot;, &quot;PlateA&quot;: &quot;SO&quot;,

# %%
# Eventually save map to interactive HTML file and display in the browser

#earthquakeMap.save("output/map_koeri.html")
#webbrowser.open(os.getcwd() + "../output/map_koeri.html")

# %% [markdown]
# ## The End
